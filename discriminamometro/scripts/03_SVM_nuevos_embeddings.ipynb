# %%
from Discriminamometro import Utileria, Discriminamometro
import pandas as pd

# Se instancia la clase del Discriminamometro
obj_Discr = Discriminamometro('PRUEBA')

# Mostramos la cantidad de tweets
print(obj_Discr.nbr_TweetsXCorrida)
# Out:
# 8

# %%
# Leemos los datasets de acuerdo a cada categoría
pd_Apariencia = obj_Discr.Utileria.AbrirJSONComoDataframe('json_apariencia.txt')
pd_Discapacidad = obj_Discr.Utileria.AbrirJSONComoDataframe('json_discapacidad.txt')
pd_Edad = obj_Discr.Utileria.AbrirJSONComoDataframe('json_edad.txt')
pd_Genero = obj_Discr.Utileria.AbrirJSONComoDataframe('json_genero.txt')
pd_Ideologia = obj_Discr.Utileria.AbrirJSONComoDataframe('json_ideologia.txt')
pd_Orientacion = obj_Discr.Utileria.AbrirJSONComoDataframe('json_orientacion.txt')
pd_Religion = obj_Discr.Utileria.AbrirJSONComoDataframe('json_religion.txt')

# Leemos también la categoría neutra
pd_Neutro = obj_Discr.Utileria.AbrirJSONComoDataframe('json_neutro.txt')

# %%
pd_Neutro
# Out:
#                  user_id                           name      screen_name  \
# 0    1078753236704731136                     Alex Cabal       AlexCabal5
# 1              100363772                            Abi      canelablood
# 2              819551708                 Luisin Jimenez   LuisinJimenezc
# 3             4074648740                         Tonino     uanerapurech
# 4             4482688119                        Saruchi      sarasanjuas
# ..                   ...                            ...              ...
# 366            137842245  T E J I D O  S O C I A L  F M   tejidosocialfm
# 367  1083124634642456576                    angiiee [?]   villalobos_an_
# 368            188558686                   Paulo Rincon         pcrincon
# 369            101864048                 Sofylaquecanta          sariway
# 370  1220000677608423424                        marbach  marbach59327032
#
#                                              full_text  \
# 0    Que pereza los "academicos" que siguen desprec...
# 1           @canelablood ay q bonita te vessss jajajaj
# 2    Analizando. En Gallup y Greensburg Luis se fue...
# 3    Con valentia y firmeza, la titular del @SATMX ...
# 4     La gente que nunca ha visto LHDP no son de fiar.
# ..                                                 ...
# 366  Reflejos condicionados, por Adriana Moran http...
# 367  Tengo una mana en fijarme en las manos de los ...
# 368  Hoy murio por Covid-19 un estudiante al que le...
# 369  Me preguntan mucho: Como puedo apoyar a tu ban...
# 370  ?Donde estabas cuando Pena Nieto...? Siendo es...
#
#                      location
# 0    Distrito Federal, Mexico
# 1                 Chicago, IL
# 2               Santo Domingo
# 3
# 4               Vigo, Galicia
# ..                        ...
# 366                 Venezuela
# 367
# 368          Bogota, Colombia
# 369    Barranquilla, Colombia
# 370
#
# [371 rows x 5 columns]

# %%
# Hacemos el proceso de limpieza
obj_Discr.str_StopWords='StopWords.p'
obj_Discr.CargarStopWords()

pd_Apariencia = obj_Discr.LimpiarDataFrame(pd_Apariencia)
pd_Discapacidad = obj_Discr.LimpiarDataFrame(pd_Discapacidad)
pd_Edad = obj_Discr.LimpiarDataFrame(pd_Edad)
pd_Genero = obj_Discr.LimpiarDataFrame(pd_Genero)
pd_Ideologia = obj_Discr.LimpiarDataFrame(pd_Ideologia)
pd_Orientacion = obj_Discr.LimpiarDataFrame(pd_Orientacion)
pd_Religion = obj_Discr.LimpiarDataFrame(pd_Religion)

pd_Neutro = obj_Discr.LimpiarDataFrame(pd_Neutro)

# %%
pd_Neutro
# Out:
#                  user_id                           name      screen_name  \
# 0    1078753236704731136                     Alex Cabal       AlexCabal5
# 1              100363772                            Abi      canelablood
# 2              819551708                 Luisin Jimenez   LuisinJimenezc
# 3             4074648740                         Tonino     uanerapurech
# 4             4482688119                        Saruchi      sarasanjuas
# ..                   ...                            ...              ...
# 366            137842245  T E J I D O  S O C I A L  F M   tejidosocialfm
# 367  1083124634642456576                    angiiee [?]   villalobos_an_
# 368            188558686                   Paulo Rincon         pcrincon
# 369            101864048                 Sofylaquecanta          sariway
# 370  1220000677608423424                        marbach  marbach59327032
#
#                                              full_text  \
# 0    que pereza los que siguen despreciando la divu...
# 1                        ay q bonita te vessss jajajaj
# 2    analizando en gallup y greensburg luis se fue ...
# 3    con valentia y firmeza la titular del raquel b...
# 4      la gente que nunca ha visto lhdp no son de fiar
# ..                                                 ...
# 366           reflejos condicionados por adriana moran
# 367  tengo una mana en fijarme en las manos de los ...
# 368  hoy murio por covid-19 un estudiante al que le...
# 369  me preguntan mucho como puedo apoyar a tu band...
# 370  donde estabas cuando pena nieto siendo espiado...
#
#                      location
# 0    Distrito Federal, Mexico
# 1                 Chicago, IL
# 2               Santo Domingo
# 3
# 4               Vigo, Galicia
# ..                        ...
# 366                 Venezuela
# 367
# 368          Bogota, Colombia
# 369    Barranquilla, Colombia
# 370
#
# [371 rows x 5 columns]

# %%
pd_Apariencia = obj_Discr.QuitarStopWordsDataFrame(pd_Apariencia)
pd_Discapacidad = obj_Discr.QuitarStopWordsDataFrame(pd_Discapacidad)
pd_Edad = obj_Discr.QuitarStopWordsDataFrame(pd_Edad)
pd_Genero = obj_Discr.QuitarStopWordsDataFrame(pd_Genero)
pd_Ideologia = obj_Discr.QuitarStopWordsDataFrame(pd_Ideologia)
pd_Orientacion = obj_Discr.QuitarStopWordsDataFrame(pd_Orientacion)
pd_Religion = obj_Discr.QuitarStopWordsDataFrame(pd_Religion)

pd_Neutro = obj_Discr.QuitarStopWordsDataFrame(pd_Neutro)

# %%
pd_Neutro
# Out:
#                  user_id                           name      screen_name  \
# 0    1078753236704731136                     Alex Cabal       AlexCabal5
# 1              100363772                            Abi      canelablood
# 2              819551708                 Luisin Jimenez   LuisinJimenezc
# 3             4074648740                         Tonino     uanerapurech
# 4             4482688119                        Saruchi      sarasanjuas
# ..                   ...                            ...              ...
# 366            137842245  T E J I D O  S O C I A L  F M   tejidosocialfm
# 367  1083124634642456576                    angiiee [?]   villalobos_an_
# 368            188558686                   Paulo Rincon         pcrincon
# 369            101864048                 Sofylaquecanta          sariway
# 370  1220000677608423424                        marbach  marbach59327032
#
#                                              full_text  \
# 0    pereza siguen despreciando divulgacion si solo...
# 1                           ay q bonita vessss jajajaj
# 2    analizando gallup greensburg luis tan alto q p...
# 3    valentia firmeza titular raquel buenrostro rot...
# 4                          gente nunca visto lhdp fiar
# ..                                                 ...
# 366               reflejos condicionados adriana moran
# 367                            mana fijarme manos maes
# 368  hoy murio covid-19 estudiante di clases semest...
# 369  preguntan puedo apoyar banda tiempos pandemia ...
# 370       pena nieto siendo espiado gobierno micolumna
#
#                      location
# 0    Distrito Federal, Mexico
# 1                 Chicago, IL
# 2               Santo Domingo
# 3
# 4               Vigo, Galicia
# ..                        ...
# 366                 Venezuela
# 367
# 368          Bogota, Colombia
# 369    Barranquilla, Colombia
# 370
#
# [371 rows x 5 columns]

# %%
# Quitamos las columnas que no nos interesan
list_ColumnasDrop = ['user_id', 'name','screen_name','location']

pd_Apariencia=pd_Apariencia.drop(list_ColumnasDrop, axis=1)
pd_Discapacidad=pd_Discapacidad.drop(list_ColumnasDrop, axis=1)
pd_Edad=pd_Edad.drop(list_ColumnasDrop, axis=1)
pd_Genero=pd_Genero.drop(list_ColumnasDrop, axis=1)
pd_Ideologia=pd_Ideologia.drop(list_ColumnasDrop, axis=1)
pd_Orientacion=pd_Orientacion.drop(list_ColumnasDrop, axis=1)
pd_Religion=pd_Religion.drop(list_ColumnasDrop, axis=1)

pd_Neutro=pd_Neutro.drop(list_ColumnasDrop, axis=1)

# %%
pd_Neutro
# Out:
#                                              full_text
# 0    pereza siguen despreciando divulgacion si solo...
# 1                           ay q bonita vessss jajajaj
# 2    analizando gallup greensburg luis tan alto q p...
# 3    valentia firmeza titular raquel buenrostro rot...
# 4                          gente nunca visto lhdp fiar
# ..                                                 ...
# 366               reflejos condicionados adriana moran
# 367                            mana fijarme manos maes
# 368  hoy murio covid-19 estudiante di clases semest...
# 369  preguntan puedo apoyar banda tiempos pandemia ...
# 370       pena nieto siendo espiado gobierno micolumna
#
# [371 rows x 1 columns]

# %%
# Agregamos una columna con la categoría que corresponde a cada grupo de tweets

pd_Apariencia['categoria'] = 'apariencia'
pd_Discapacidad['categoria'] = 'discapacidad'
pd_Edad['categoria'] = 'edad'
pd_Genero['categoria'] = 'genero'
pd_Ideologia['categoria'] = 'ideologia'
pd_Orientacion['categoria'] = 'orientacion'
pd_Religion['categoria'] = 'religion'

pd_Neutro['categoria'] = 'neutro'

# %%
pd_Neutro
# Out:
#                                              full_text categoria
# 0    pereza siguen despreciando divulgacion si solo...    neutro
# 1                           ay q bonita vessss jajajaj    neutro
# 2    analizando gallup greensburg luis tan alto q p...    neutro
# 3    valentia firmeza titular raquel buenrostro rot...    neutro
# 4                          gente nunca visto lhdp fiar    neutro
# ..                                                 ...       ...
# 366               reflejos condicionados adriana moran    neutro
# 367                            mana fijarme manos maes    neutro
# 368  hoy murio covid-19 estudiante di clases semest...    neutro
# 369  preguntan puedo apoyar banda tiempos pandemia ...    neutro
# 370       pena nieto siendo espiado gobierno micolumna    neutro
#
# [371 rows x 2 columns]

# %%
# Juntamos todos los dataset en uno solo
pd_Todos = pd.DataFrame(columns=['full_text','categoria'])

pd_Todos = pd_Todos.append(pd_Apariencia)
pd_Todos = pd_Todos.append(pd_Discapacidad)
pd_Todos = pd_Todos.append(pd_Edad)
pd_Todos = pd_Todos.append(pd_Genero)
pd_Todos = pd_Todos.append(pd_Ideologia)
pd_Todos = pd_Todos.append(pd_Orientacion)
pd_Todos = pd_Todos.append(pd_Religion)
pd_Todos = pd_Todos.append(pd_Neutro)

# %%
#pd_Todos.to_csv('muestra.csv')

# %%
from sklearn.utils import shuffle
pd_Todos = shuffle(pd_Todos)

# %%
pd_Todos
# Out:
#                                              full_text     categoria
# 157  repostear memes malo memes repostearlo puto di...   orientacion
# 100  acusa caldo loret mas companero john sino tamb...     ideologia
# 342  mmm senor criticaba chumel mmmm ponian delante...  discapacidad
# 29                      puta madre espante feo casi da        genero
# 3                               asi pinche nino toxico          edad
# ..                                                 ...           ...
# 48                          abre puto whatsapp cojones   orientacion
# 244                               pues alguno especial    apariencia
# 329  vestir ropa marca ser jodido recuerda familia ...    apariencia
# 163  jajajaja dictan lista super patetico pinche vi...          edad
# 148  demuestra jodido saber pudiste despedir amigos...    apariencia
#
# [2996 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(pd_Todos, test_size=0.2)

# %%
# Training Support Vector Machines - SVM and calculating its performance
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import TfidfTransformer
text_clf_svm = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
                         ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, max_iter=5, random_state=42))])

text_clf_svm = text_clf_svm.fit(train.full_text, train.categoria)
predicted_svm = text_clf_svm.predict(test.full_text)
np.mean(predicted_svm == test.categoria)
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_stochastic_gradient.py:557: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# 0.9

# %%
predicted_svm = text_clf_svm.predict(['Ese compa es un maricon'])
predicted_svm
# Out:
# array(['orientacion'], dtype='<U12')

# %%
predicted_svm = text_clf_svm.predict(['Eres muy joven para entenderlo'])
predicted_svm
# Out:
# array(['edad'], dtype='<U12')

# %%
predicted_svm = text_clf_svm.predict(['Hoy es un día muy bonito'])
predicted_svm
# Out:
# array(['orientacion'], dtype='<U12')

# %%
predicted_svm = text_clf_svm.predict(['Eres gordo'])
predicted_svm
# Out:
# array(['apariencia'], dtype='<U12')

# %%
predicted_svm = text_clf_svm.predict(['cojo rico'])
predicted_svm
# Out:
# array(['discapacidad'], dtype='<U12')

# %%
 #################################### Propuesta con Embeddings ####################################

# %%
train.shape
# Out:
# (2396, 2)

# %%
import spacy
import numpy as np

# Load the spacy model that you have installed
nlp = spacy.load('es_core_news_lg')

# %%
nlp("tonto tonto").vector.shape
# Out:
# (300,)

# %%
npEmbeddings = np.empty([0, 300])

for texto in train['full_text']:
    
    #print(texto)
    
    # process a sentence using the model
    doc = nlp(texto)
    
    # print(doc.vector.shape)
    if doc.vector.shape[0]==300:
        npEmbeddings = np.append(npEmbeddings, [doc.vector], axis = 0)
    else:
        npAux = np.empty([1, 300])
        npEmbeddings = np.append(npEmbeddings, npAux, axis = 0)

npEmbeddings.shape
# Out:
# (2396, 300)

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, max_iter=5, random_state=42).fit(npEmbeddings, train.categoria)
clf
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_stochastic_gradient.py:557: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# SGDClassifier(alpha=0.001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=5,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=42, shuffle=True, tol=0.001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
npEmbeddings = np.empty([0, 300])
for texto in test['full_text']:
    
    #print(frase)
    
    # process a sentence using the model
    doc = nlp(texto)
    
    # print(doc.vector.shape)
    #print(npEmbeddings.shape)
    #print(doc.vector.shape)
    
    if doc.vector.shape[0]==300:
        npEmbeddings = np.append(npEmbeddings, [doc.vector], axis = 0)
    else:
        npAux = np.empty([1, 300])
        doc = nlp('prueba')
        #npEmbeddings = np.append(npEmbeddings, npAux, axis = 0)
        npEmbeddings = np.append(npEmbeddings, [doc.vector], axis = 0)
        predicted_svm = clf.predict([doc.vector])
        
npEmbeddings.shape
# Out:
# (600, 300)

# %%
predicted_svm = clf.predict(npEmbeddings)
np.mean(predicted_svm == test.categoria)
# Out:
# 0.7333333333333333

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test.categoria,predicted_svm)
# Out:
# array([[52,  1,  1,  0,  0,  4,  1,  6],
#        [ 0, 75,  6,  0,  0,  1,  1,  5],
#        [ 0,  2, 50,  0,  3,  5,  1,  4],
#        [ 0,  3,  1, 76,  1,  1,  0,  7],
#        [ 5,  3,  3,  1, 57,  7,  3,  4],
#        [ 6,  5,  7,  4, 18, 31,  6,  6],
#        [ 0,  1,  3,  1,  1,  0, 46,  5],
#        [ 1,  3,  4,  0,  4,  5,  0, 53]])

# %%
npAux = nlp('Ese compa es un maricon').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['apariencia'], dtype='<U12')

# %%
npAux = nlp('Eres muy joven para entenderlo').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['apariencia'], dtype='<U12')

# %%
npAux = nlp('Hoy es un día muy bonito').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['apariencia'], dtype='<U12')

# %%
npAux = nlp('Eres gordo').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['edad'], dtype='<U12')

# %%
npAux = nlp('Cojo rico').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['discapacidad'], dtype='<U12')

# %%
npAux = nlp('abran traen mamadas puta sabalero').vector
predicted_svm = clf.predict([npAux])
predicted_svm
# Out:
# array(['genero'], dtype='<U12')

# %%
npAux2 = nlp('hijos puta kirchneristas prendian fuego pais fmi ahora mitad pais pobre dijo literalmente iba tratar tema ive dicen sola palabra').vector
predicted_svm = clf.predict([npAux2])
predicted_svm
# Out:
# array(['genero'], dtype='<U12')

# %%
# doc1.similarity(doc2)
npAux = nlp('abran traen mamadas puta sabalero')
npAux2 = nlp('hijos puta kirchneristas prendian fuego pais fmi ahora mitad pais pobre dijo literalmente iba tratar tema ive dicen sola palabra')
npAux.similarity(npAux2)
# Out:
# 0.37180204020797225

# %%
pd_Todos.head(10)
# Out:
#                                              full_text     categoria
# 157  repostear memes malo memes repostearlo puto di...   orientacion
# 100  acusa caldo loret mas companero john sino tamb...     ideologia
# 342  mmm senor criticaba chumel mmmm ponian delante...  discapacidad
# 29                      puta madre espante feo casi da        genero
# 3                               asi pinche nino toxico          edad
# 165  desarrollo minindustrias cuba sido paso decisi...  discapacidad
# 147  decir reconocimiento va cambiar hecho mundialm...          edad
# 155                            sale favor fraude segun        neutro
# 141         verdad si profesores estan abusando tareas          edad
# 325             ensalada atun mas puto delicioso mundo   orientacion

# %%
pd_Todos["full_text"].iloc[2]
# Out:
# 'mmm senor criticaba chumel mmmm ponian delante ejemplo lucha favor clasismo racismo demas jajajaja mas rapido cae hablador cojo'

# %%
pd_Todos["full_text"].iloc[9]
# Out:
# 'ensalada atun mas puto delicioso mundo'

# %% [markdown]
# # EMBEDDING CORRIENDO

# %%
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec

path = get_tmpfile("./data/word2vec.model")

model = Word2Vec(common_texts, size=100, window=5, min_count=1, workers=4)
model.wv.save_word2vec_format("./data/word2vec.txt")

# %%
model.wv.save_word2vec_format("./data/word2vec.txt")

# %%
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
nlp = spacy.load("./data/prueba/")

# %%
nlp("human").vector
# Out:
# array([ 2.5868422e-04,  2.8346865e-03, -6.0029706e-04,  4.8892600e-03,
#         2.0923477e-03, -1.1058900e-03,  2.7277637e-03, -2.1610716e-03,
#        -4.5559690e-03, -3.4200142e-03, -4.2735832e-03, -2.9004815e-03,
#         3.5243565e-03, -7.2944607e-04,  2.7589609e-05, -3.9621075e-03,
#        -3.3722632e-03,  8.0615480e-04,  5.2687206e-04, -2.5914721e-03,
#        -4.3145131e-04,  1.0758716e-03,  2.6561369e-03,  4.9398467e-03,
#         4.0651861e-04, -2.6435084e-03,  3.1350187e-03,  3.5871980e-03,
#        -4.9136523e-03,  1.4117392e-03,  4.1364869e-03,  1.1893999e-03,
#        -1.3337638e-03, -5.6215958e-04, -4.9207476e-03,  1.9034136e-03,
#         1.0762394e-03,  3.5155865e-03, -4.1497822e-04, -4.4712916e-04,
#        -3.1488913e-04, -4.3498906e-03, -2.7774950e-03,  3.7700575e-04,
#         2.3892167e-04,  4.5448001e-03,  4.6179811e-03, -3.0650154e-03,
#        -2.6180320e-03,  4.4442215e-03,  4.9036629e-03,  3.5073441e-03,
#         3.2773309e-03, -3.4846216e-03,  3.6804408e-03, -2.7728206e-03,
#        -3.0586447e-03, -4.3016574e-03,  3.4870713e-03, -8.9363073e-04,
#        -3.3888684e-03, -2.5686764e-03, -3.0816752e-03, -4.1927118e-03,
#         3.8693016e-03, -3.2810783e-03, -4.6271859e-03,  8.1653439e-04,
#         2.9051569e-03,  3.9710230e-03,  4.1269849e-04,  4.1497163e-03,
#        -4.8116995e-03,  3.4966008e-03,  9.8136056e-04,  2.8191505e-03,
#        -6.8763003e-04, -1.1449063e-03,  2.4217539e-03,  3.9030417e-04,
#         4.7451705e-03,  3.8191683e-03, -3.3822400e-03, -1.4719123e-03,
#        -7.0790038e-04,  4.4982876e-03, -1.2376552e-03, -2.5181586e-03,
#        -8.3338330e-04,  2.1423236e-03,  1.5751284e-03, -2.0253612e-03,
#        -4.7194548e-03, -4.5070993e-03, -2.6795943e-03, -4.1280556e-03,
#         9.3110581e-04,  2.0573800e-03, -4.1996422e-03,  4.2365072e-03],
#       dtype=float32)

# %% [markdown]
# # PRUEBA MÁS DIFÍCIL

# %%
pd_Todex = pd_Todos["full_text"]

# %%
pd_Todex
# Out:
# 157    repostear memes malo memes repostearlo puto di...
# 100    acusa caldo loret mas companero john sino tamb...
# 342    mmm senor criticaba chumel mmmm ponian delante...
# 29                        puta madre espante feo casi da
# 3                                 asi pinche nino toxico
#                              ...
# 48                            abre puto whatsapp cojones
# 244                                 pues alguno especial
# 329    vestir ropa marca ser jodido recuerda familia ...
# 163    jajajaja dictan lista super patetico pinche vi...
# 148    demuestra jodido saber pudiste despedir amigos...
# Name: full_text, Length: 2996, dtype: object

# %%
from nltk import word_tokenize
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/francisco/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pd_Todex2 = pd_Todex.apply(word_tokenize)

# %%
pd_Todex2.to_list()
# Out:
# [['repostear',
#   'memes',
#   'malo',
#   'memes',
#   'repostearlo',
#   'puto',
#   'dia',
#   'siguiente',
#   'plano',
#   'tener',
#   'madre',
#   'xdddd'],
#  ['acusa',
#   'caldo',
#   'loret',
#   'mas',
#   'companero',
#   'john',
#   'sino',
#   'tambien',
#   'mexicanos',
#   '4t',
#   'usted',
#   'nomas',
#   'llego',
#   'hacerle',
#   'caldo',
#   'gordo',
#   'exigimos',
#   'q',
#   'deje',
#   'hacerlo'],
#  ['mmm',
#   'senor',
#   'criticaba',
#   'chumel',
#   'mmmm',
#   'ponian',
#   'delante',
#   'ejemplo',
#   'lucha',
#   'favor',
#   'clasismo',
#   'racismo',
#   'demas',
#   'jajajaja',
#   'mas',
#   'rapido',
#   'cae',
#   'hablador',
#   'cojo'],
#  ['puta', 'madre', 'espante', 'feo', 'casi', 'da'],
#  ['asi', 'pinche', 'nino', 'toxico'],
#  ['desarrollo',
#   'minindustrias',
#   'cuba',
#   'sido',
#   'paso',
#   'decisivo',
#   'desarrollo',
#   'economia',
#   'media',
#   'luna',
#   'ciegodeavila',
#   'ejemplo',
#   'cuanto',
#   'logra',
#   'abre',
#   'paso',
#   'nuevas',
#   'gestiones',
#   'produccion',
#   'pormenores'],
#  ['decir',
#   'reconocimiento',
#   'va',
#   'cambiar',
#   'hecho',
#   'mundialmente',
#   'conocidas',
#   'estan',
#   'esperando',
#   'comeback',
#   'ustedes',
#   'intentando',
#   'invalidar',
#   'impacto',
#   'va',
#   'cambiar',
#   'hecho',
#   'ustedes',
#   'inventando',
#   'cosas',
#   'va',
#   'cambiar',
#   'realidad'],
#  ['sale', 'favor', 'fraude', 'segun'],
#  ['verdad', 'si', 'profesores', 'estan', 'abusando', 'tareas'],
#  ['ensalada', 'atun', 'mas', 'puto', 'delicioso', 'mundo'],
#  ['gracias', 'nena'],
#  ['entiendo',
#   'logro',
#   'comprender',
#   'carajos',
#   'ser',
#   'tan',
#   'sensible',
#   'ahogarme',
#   'puto',
#   'vaso',
#   'agua'],
#  ['sabes',
#   'si',
#   'mineria',
#   'sigue',
#   'mocho',
#   'ultima',
#   'vez',
#   'quitaron',
#   'stopmi',
#   'corazon',
#   'rompio'],
#  ['dice',
#   'proverbio',
#   'culpa',
#   'ciego',
#   'sino',
#   'da',
#   'vale',
#   'decir',
#   'gringos',
#   'pagar',
#   'junto',
#   'miserables',
#   'dano',
#   'causado'],
#  ['quede',
#   'constancia',
#   'declaracion',
#   'tipo',
#   'entendimiento',
#   'acerca',
#   'democracia',
#   'separacion',
#   'poderes',
#   'acaso',
#   'creen',
#   'chairo',
#   'enloquecido',
#   'persona',
#   'ser',
#   'considerado',
#   'miembro',
#   'comite',
#   'tecnico'],
#  ['entra', 'toda', 'bien', 'castigada', 'esquina', 'cama'],
#  ['telerisa',
#   'fascina',
#   'mantiene',
#   'mocho',
#   'homofobo',
#   'racista',
#   'clasista',
#   'esteban',
#   'arce',
#   'arroban',
#   'bloqueo'],
#  ['rolen', 'only', 'micaela', 'mirabai', 'pobre', 'ciego'],
#  ['cora',
#   'mocho',
#   'sellado',
#   'tetra',
#   'karma',
#   'roto',
#   'dijo',
#   'maldita',
#   'coneja'],
#  ['ja', 'ja', 'ja', 'ja', 'dice', 'maricon', 'c-19'],
#  ['hijo', 'puta', 'cuanto', 'pago', 'j3fa', 'mafia', 'argentina'],
#  ['empezaron', 'aca', 'pueblo', 'mochono', 'mmn'],
#  ['pinche', 'viejito', 'presiente', 'inepto'],
#  ['puta', 'pena', 'ver', 'historia', 'alguien', '27s'],
#  ['pidio',
#   'perdon',
#   'unico',
#   'recuerdo',
#   'messi',
#   'hizo',
#   'gol',
#   'sente',
#   'butaca',
#   'llorar',
#   'nina',
#   'chiquita',
#   'pude',
#   'ver',
#   'mas',
#   'igual',
#   'feliz',
#   'cumpleanos',
#   'messi',
#   '[',
#   ']'],
#  ['orale',
#   'favor',
#   'promueve',
#   'parejas',
#   'mismo',
#   'sexo',
#   'considera',
#   'abominacion',
#   'muchas',
#   'cosas',
#   'mas',
#   'ahi',
#   'que',
#   '[',
#   ']',
#   '[',
#   ']',
#   'gomes',
#   'morin',
#   'revolcando',
#   'tumba',
#   'hipocritas',
#   'corruptos'],
#  ['ojo', 'mundo', 'terminara', 'mohandas', 'gandhi'],
#  ['peor', 'ciego', 'quiere', 'ver'],
#  ['diria',
#   'chairo',
#   'si',
#   'lopez',
#   'sabia',
#   'defenderlo',
#   'hace',
#   'pensar',
#   'sabe',
#   'existencia',
#   'defendera'],
#  ['pinche',
#   'viejito',
#   'bien',
#   'culero',
#   'rencoroso',
#   'aunque',
#   'merezca',
#   'paso',
#   'verga',
#   'neta'],
#  ['fulana',
#   'dice',
#   'buena',
#   'persona',
#   'hecha',
#   'discurso',
#   'buena',
#   'moral',
#   'toda',
#   'casaca',
#   'envidia',
#   'traicionado',
#   'mmm',
#   'bien',
#   'doble',
#   'moral',
#   'convence',
#   'discurso',
#   'mojigata',
#   'haciendo',
#   'vistima'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['ladyprimeraclase',
#   'siii',
#   'claro',
#   'austeridad',
#   'si',
#   'claro',
#   'pinche',
#   'viejito',
#   'mentiroso'],
#  ['pais', 'pinchar', 'telefono', 'pellizco', 'mocho', 'cualquiera', 'hace'],
#  ['pobre', 'cosita', 'fea', 'xdd'],
#  ['analysis',
#   'comun',
#   'urnas',
#   'voto',
#   'pueblo',
#   'aleja',
#   'mas',
#   'mas',
#   'izquierda',
#   'separatismo',
#   'pueblo',
#   'ciego',
#   'sordo',
#   'inteligente',
#   'grita',
#   'protesta',
#   'destruye',
#   'expresa',
#   'tambien',
#   'voto'],
#  ['facil',
#   'vuelve',
#   'dejar',
#   'ir',
#   'personas',
#   'vida',
#   'aplica',
#   'amores',
#   'amistades',
#   'familia'],
#  ['argentina',
#   'ministro',
#   'economia',
#   'sino',
#   'deuda',
#   'negocia',
#   'acreedores',
#   'ciego',
#   'destruccion',
#   'economia',
#   'coronavirus',
#   'pbi',
#   'cayo',
#   '-54',
#   '%',
#   'inversion',
#   '-18',
#   '%',
#   'emision',
#   'monetaria',
#   '155',
#   '%',
#   'siguen',
#   'creyendo',
#   'necesitan',
#   'plan'],
#  ['deje', 'hacerse', 'pendejo', 'pinche', 'viejito'],
#  ['aleluya',
#   'gloria',
#   'dios',
#   'ojala',
#   'gob',
#   'julio',
#   'leon',
#   'h',
#   'mande',
#   'canaveral',
#   'mpio',
#   'independencia',
#   'san',
#   'felipe',
#   'yaracuy',
#   'q',
#   'bastante',
#   'falta',
#   'hacen',
#   'abuelas',
#   'q',
#   'caminar',
#   'mas',
#   '2',
#   'km',
#   'comprar',
#   '2km',
#   'regresar',
#   'quitaron',
#   'yutong',
#   'q',
#   'habia',
#   'aqui'],
#  ['si',
#   'pones',
#   'pensar',
#   'mayor',
#   'prianista',
#   'amlo',
#   'viene',
#   'pri',
#   'quiere',
#   'ser',
#   'salinas',
#   'mas',
#   'mocho',
#   'pan',
#   'prian',
#   'amlo',
#   'lopezobrador_'],
#  ['siento', 'triste', 'mocho'],
#  ['enemigo',
#   'd',
#   'mexicano',
#   'mexicano',
#   'gana',
#   'oro',
#   'mundo',
#   'nino',
#   'campeon',
#   'pobres',
#   'campeona',
#   'pdte',
#   'd',
#   'mex',
#   'mediocres',
#   'q',
#   'pueden',
#   'ver',
#   'mas',
#   'alla',
#   'd',
#   'prejuicios',
#   'ideologicos'],
#  ['cora',
#   'mocho',
#   'sellado',
#   'tetra',
#   'karma',
#   'roto',
#   'dijo',
#   'maldita',
#   'coneja'],
#  ['aqui', 'si', 'puedo', 'escribirlo', 'baneen', 'si', 'joto'],
#  ['mocho', 'propaganda', 'ponal'],
#  ['sabes',
#   'razon',
#   'mejor',
#   'dedico',
#   'coros',
#   'cantatas',
#   'franz',
#   'verme',
#   'naco'],
#  ['gustando', 'cabello', 'mocho', 'hagrid'],
#  ['ah',
#   'bonito',
#   'lastima',
#   '1',
#   'religion',
#   'hablo',
#   '2',
#   'vas',
#   'poder',
#   'desviar',
#   'tema',
#   'lopez',
#   '(',
#   'por',
#   'dile',
#   'lopez',
#   'bien',
#   'mocho'],
#  ['grosero',
#   'vas',
#   'ir',
#   'infierno',
#   'malhablado',
#   'recuerda',
#   'siempre',
#   'seguir',
#   'palabra',
#   'dios',
#   'si',
#   'dice',
#   'lances',
#   'edificio',
#   'hazlo',
#   'avientes',
#   'trafico',
#   'hazlo',
#   'pinche',
#   'hipocrita',
#   'mocho'],
#  ['atrasas', '15', 'minutos', 'pago', 'cfe'],
#  ['hicieron',
#   'publico',
#   'tenian',
#   'guardado',
#   'semejantes',
#   'ladrones',
#   'corruptos',
#   'mas',
#   'vos',
#   'jodido',
#   'juzgados'],
#  ['ay',
#   'desaparece',
#   'grandisimo',
#   'arrastrado',
#   'lambiscon',
#   'encima',
#   'mandilon',
#   'nivel',
#   'imbecil'],
#  ['basado', 'toda', 'puta', 'vida', 'solo', 'ahora', 'moda'],
#  ['hirian',
#   'axel',
#   'segura',
#   'vazquez',
#   'discapacitado',
#   'pide',
#   'ayuda',
#   'lleva',
#   'ano',
#   'medio',
#   'encontrar',
#   'empleo'],
#  ['puto',
#   'polvo',
#   'sahara',
#   'arribo',
#   'mexico',
#   'dia',
#   'ayer',
#   'peninsula',
#   'yucatan',
#   'espera',
#   'hoy',
#   'extienda',
#   'lado',
#   'golfo',
#   'pacifico',
#   'paro',
#   'comunicaciones',
#   'aereas',
#   'paises',
#   'sudamerica',
#   'pinche',
#   '2020',
#   'mas',
#   'espera'],
#  ['tuit', 'pregunta', 'vas', 'votar', 'chairo', 'pendejo'],
#  ['jodido', 'dubai', 'torreon'],
#  ['salia', 'jajajaja'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['constancia',
#   'discapacitado',
#   'ser',
#   'discapacitado',
#   'gozan',
#   'buena',
#   'salud',
#   'ningun',
#   'impedimento',
#   'fisicodelegado',
#   'taddeihay',
#   'personas',
#   'verdaderamente',
#   'necesitan',
#   'apoyosen',
#   'sonora',
#   'estan',
#   'desviando',
#   'voluntad',
#   'apoyar'],
#  ['felicidades',
#   'deseando',
#   'pases',
#   'dia',
#   'super',
#   'machin',
#   'familia',
#   'exito',
#   'dios',
#   'llene',
#   'salud',
#   'amor',
#   'dinero',
#   'orden',
#   'abrazote'],
#  ['puta', 'madre', 'pudiera'],
#  ['quede',
#   'constancia',
#   'declaracion',
#   'tipo',
#   'entendimiento',
#   'acerca',
#   'democracia',
#   'separacion',
#   'poderes',
#   'acaso',
#   'creen',
#   'chairo',
#   'enloquecido',
#   'persona',
#   'ser',
#   'considerado',
#   'miembro',
#   'comite',
#   'tecnico'],
#  ['puedo',
#   'jugar',
#   'puedo',
#   'ver',
#   'torneo',
#   'warzone',
#   'jodido',
#   'internet',
#   'odio',
#   'puto'],
#  ['jajajajaja',
#   'describiste',
#   'chaira',
#   'esteban',
#   'arce',
#   'mames',
#   'mocho',
#   'presbitero'],
#  ['ayer', 'enfermera', 'mocho', 'unas', '[', ']'],
#  ['si', 'cojo', 'poquito', 'menos', 'guste'],
#  ['puto', 'kalbo', 'cojones'],
#  ['verdas',
#   'hijos',
#   'puta',
#   'dinero',
#   'quiero',
#   'comprarme',
#   'entrada',
#   'primavera'],
#  ['mas', 'jodido'],
#  ['reflejos', 'condicionados', 'adriana', 'moran'],
#  ['brother',
#   'llamarlo',
#   'asi',
#   'anda',
#   'comprate',
#   'tapa',
#   'ojos',
#   'cuero',
#   'usan',
#   'caballos',
#   'anteojos',
#   'culo',
#   'botella',
#   'igual',
#   'tres',
#   'monos',
#   'ciego',
#   'dos',
#   'lexico',
#   'existe',
#   'palabra',
#   'imparcialidad',
#   'ser',
#   'descarado'],
#  ['uhhhh', 'amlo', 'si', 'visa', 'noooooo', 'naco', 'pobreton', 'ahora'],
#  ['yey', 'ahora', 'regresara', 'burro', 'joto'],
#  ['llego',
#   'hora',
#   'nini',
#   'tio',
#   'salinas',
#   'va',
#   'seguir',
#   'cargando',
#   'licenciado',
#   'universitario',
#   'mas',
#   'habil',
#   'asuntos',
#   'ciao'],
#  ['jajaja', 'pinche', 'vinas', 'jodido', 'muero', 'hambre'],
#  ['llevo',
#   '1',
#   'dia',
#   'usando',
#   'edge',
#   'digo',
#   'jodido',
#   'mejor',
#   'navegador',
#   'patea',
#   '10',
#   'veces',
#   'culo',
#   'chrome',
#   'amo'],
#  ['ugh',
#   'dejo',
#   'pensar',
#   'sensacion',
#   'puto',
#   'piso',
#   'moviendose',
#   'lado',
#   'lado',
#   'situacion',
#   'mas',
#   'estresante',
#   'desagradable'],
#  ['pues', 'imbecil', 'trabajo', 'espero', 'beca', 'nini'],
#  ['odio',
#   'nina',
#   'solamente',
#   'hizo',
#   'recordar',
#   'mal',
#   'andaba',
#   'alla',
#   'dos',
#   'mil',
#   'diecinueve',
#   'puta',
#   'nina'],
#  ['saben',
#   'q',
#   'louis',
#   'youtubers',
#   'britanicos',
#   'veces',
#   'dom',
#   'entiendo',
#   'q',
#   'dicen',
#   'yankees',
#   'm',
#   're',
#   'cuesta',
#   'porq',
#   'hablan',
#   'tan',
#   'mal',
#   'hijos',
#   'puta'],
#  ['nini**', 'erros'],
#  ['dracupayaso', 'espalda', 'puto', 'oso', 'yogi'],
#  ['queriendo', 'ganas', 'hablar', 'mutuas'],
#  ['habia', 'visto', 'manera'],
#  ['viendo',
#   'marido',
#   'paciente',
#   'quiere',
#   'baje',
#   'peso',
#   'puto',
#   'loco',
#   'habria',
#   'mandado',
#   'mierda'],
#  ['hey',
#   'recibe',
#   'limosna',
#   'mensual',
#   'verdad',
#   'vale',
#   'brga',
#   'futuro',
#   'hijos',
#   'nietos',
#   'consciente',
#   'condenando',
#   'pais',
#   'jodido',
#   'aspiraciones',
#   'va',
#   'llevar',
#   'chngada',
#   'pvtas',
#   'moneditas',
#   'mames'],
#  ['da',
#   'mucha',
#   'risa',
#   'decirle',
#   'pendejo',
#   '>',
#   '>',
#   'puto',
#   '>',
#   '>',
#   'amigos'],
#  ['digas',
#   'mmmanon',
#   'payaso',
#   'deja',
#   'alardear',
#   'sismo',
#   'si',
#   'valen',
#   'madre',
#   'mexicanos',
#   'robar',
#   'diste',
#   'dinero',
#   'hijo',
#   'jose',
#   'ramon',
#   'nini',
#   'huevon',
#   'pa',
#   'comprar',
#   '2',
#   'deptos',
#   'lujo',
#   'california',
#   'casa',
#   'campo',
#   'espana',
#   'dices',
#   'tener',
#   'dinero'],
#  ['leido',
#   'sigo',
#   'trabajo',
#   'asi',
#   'dice',
#   'interesante',
#   'entrevista',
#   'esperan',
#   'renovar',
#   'coordinacion',
#   'dijo',
#   'tiempodedefiniciones'],
#  ['sorprende',
#   'pinche',
#   'problema',
#   'covid19',
#   'todavia',
#   'personas',
#   'puedan',
#   'dejar',
#   'puto',
#   'cigarro'],
#  ['debemos', 'proteger', 'sticky', 'ma', 'toda', 'costa'],
#  ['man', 'marica', 'mocho', 'teta', 'si'],
#  ['preso',
#   'hizo',
#   'viral',
#   'subir',
#   'tiktoks',
#   'gente',
#   'festeja',
#   'delito',
#   'apunalo',
#   '11',
#   'veces',
#   'nena',
#   'sigan',
#   'festejandole',
#   'hijos',
#   'puta',
#   'encima',
#   'justifican',
#   'derechos',
#   'humanos',
#   'ojala',
#   'mueran'],
#  ['puto',
#   'madrid',
#   'siempre',
#   'extramotivandose',
#   'valencia',
#   'dandolo',
#   'siguiente',
#   'haciendo',
#   'ridiculo',
#   'grande',
#   'andorra'],
#  ['pinche', 'viejito', 'ridiculo'],
#  ['progresando',
#   'pais',
#   'dicen',
#   'vamos',
#   'primer',
#   'mundo',
#   'california',
#   'mas',
#   'cerca',
#   'malo',
#   'presidente',
#   'mocho',
#   'vela',
#   'perpetua'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['razon', 'amigomejor', 'dedico', 'rach', '3', 'pa', 'verme', 'naco'],
#  ['cacapets', 'cacabots', 'jajajajajajajajaja', 'recibiste', 'cheque', 'nini'],
#  ['debe',
#   'reconsiderarse',
#   'cobro',
#   'iva',
#   'regresar',
#   'isim',
#   'apuesta',
#   'cadena',
#   'produccion-consumidor',
#   'reciba',
#   'impuesto',
#   'compensable',
#   'mano',
#   'obra',
#   'utilidad',
#   'error',
#   'empresa',
#   'buscara',
#   'siempre',
#   'compensar',
#   'iva',
#   'facturas',
#   'apocrifas',
#   'jodido',
#   'consumidor',
#   'final'],
#  ['fifi',
#   'nini',
#   'afiliado',
#   'ningun',
#   'menos',
#   'chayote',
#   'aun',
#   'menos',
#   'comprado',
#   'solo',
#   'ciudadano',
#   'mas',
#   'expresando',
#   'sentir'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['serio',
#   'redamlo',
#   'dicen',
#   'derecha',
#   'derrotada',
#   'da',
#   'mas',
#   'salen',
#   'noticias',
#   'peor',
#   'ciego',
#   'quiere',
#   'ver',
#   'morenaesunpeligroparamexico',
#   'mas',
#   'confirmado',
#   'amlofracasopresidencial'],
#  ['si',
#   'informan',
#   'narcos',
#   'corruptos',
#   'dinero',
#   'desviste',
#   'hijo',
#   'jose',
#   'ramon',
#   'nini',
#   'huevon'],
#  ['reunion',
#   'estrategica',
#   'red',
#   'mujeres',
#   'derechos',
#   'mujeres',
#   'ninas',
#   'prioridad',
#   'frente',
#   'desafios',
#   'presenta',
#   'periodo',
#   '2020-2021'],
#  ['bien', 'ciego'],
#  ['weona', 'rastrera', 'mojigata', 'hipocrita'],
#  ['sientes', 'nini', 'ojala', 'mejores'],
#  ['gustaria', 'ser', 'naco'],
#  ['hoy', 'cumple', 'gracias', 'tantas', 'alegrias', 'primer', 'dia', 'roman'],
#  ['jajajajaja', 'pinche', 'viejito'],
#  ['dicen', 'bien', 'nadie', 'dice', 'bien'],
#  ['mas', 'pronto', 'cae', 'cojo'],
#  ['polvodelsahara',
#   'ver',
#   'torreon',
#   'mamen',
#   'informense',
#   'porquito',
#   'puta',
#   'madre'],
#  ['na',
#   'guara',
#   'cara',
#   'chamo',
#   'esposa',
#   'va',
#   'sabe',
#   'jodido',
#   'vivir',
#   'vaina',
#   'revienta',
#   'gente',
#   'resolver',
#   'papa',
#   'cada',
#   'dia',
#   'escenas',
#   'pegan',
#   'corazon',
#   'solo',
#   'comprende',
#   'vivio'],
#  ['estimados',
#   'super',
#   'duper',
#   'humanos',
#   'reunios',
#   'puta',
#   'madre',
#   'ustedes',
#   'interpretan',
#   'forma',
#   'rara',
#   'idioma',
#   'nombre',
#   'organizacion',
#   'avengers',
#   'correcto',
#   'buen',
#   'espanol'],
#  ['despues', 'comerme', 'mitad', 'mostachon', 'solita', '100', 'vida', 'fit'],
#  ['solo',
#   'vengo',
#   'recordarles',
#   'interior',
#   'pais',
#   'puta',
#   'idea',
#   'diferencia',
#   'caba',
#   'amba',
#   'capital',
#   'provincia'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['moraleja',
#   'george',
#   'carlin',
#   'don',
#   'rickles',
#   'richard',
#   'jeni',
#   'haberse',
#   'ido',
#   'hbo',
#   'volviera',
#   'santurron',
#   'cobarde',
#   'sumiso',
#   'censor',
#   'despedido',
#   'primera'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['hace',
#   'idea',
#   'logica',
#   'inapropiada',
#   'sera',
#   'otorgarles',
#   'restaurantes',
#   'zona',
#   'exclusiva',
#   'transito',
#   'vehiculos',
#   'seria',
#   'estrangulada',
#   'generando',
#   'mas',
#   'trafico'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['bien', 'mojigata', 'si', 'agarro', 'cogiendo', 'tomo', 'foto'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['soros'],
#  ['analizando',
#   'gallup',
#   'greensburg',
#   'luis',
#   'tan',
#   'alto',
#   'q',
#   'provocado',
#   'q',
#   'leonelistas',
#   'gobiernistas',
#   'comiencen',
#   'coincidir',
#   'temas',
#   'acaban',
#   'd',
#   'gran',
#   'sueno',
#   'pensaban',
#   'q',
#   'peligro',
#   'gonzalo',
#   'leonel',
#   'q',
#   'peligro',
#   'leonel',
#   'gonzalo',
#   'luis',
#   'colo'],
#  ['quede',
#   'constancia',
#   'declaracion',
#   'tipo',
#   'entendimiento',
#   'acerca',
#   'democracia',
#   'separacion',
#   'poderes',
#   'acaso',
#   'creen',
#   'chairo',
#   'enloquecido',
#   'persona',
#   'ser',
#   'considerado',
#   'miembro',
#   'comite',
#   'tecnico'],
#  ['luctuosa',
#   'l',
#   'yendy',
#   'garo',
#   'perez',
#   'mejor',
#   'conocido',
#   'fallecio',
#   'hospital',
#   'juan',
#   'pablo',
#   'pina',
#   'provincia',
#   'san',
#   'cristobal',
#   'asi',
#   'confirmo',
#   'doctor',
#   'felix',
#   'antonio',
#   'cruz',
#   'jiminian',
#   'programa',
#   'show',
#   'listindiario'],
#  ['entres',
#   'casa',
#   'persona',
#   'vuelvete',
#   'vayas',
#   'ir',
#   'vuelvete',
#   'ensenaron',
#   'lugar',
#   'intimo',
#   'minimo',
#   'puedes',
#   'hacer',
#   'respetar'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['mmm', 'asi', 'ser', 'nini'],
#  ['si', 'eh', 'hipocrita'],
#  ['huachicolerote',
#   'da',
#   'apoyo',
#   'gobierno',
#   'ninite',
#   'becan',
#   'robas',
#   'luzte',
#   'condonan',
#   'deuda',
#   'ladron',
#   'cuello',
#   'blancote',
#   'senador',
#   'ciudadano',
#   'decentete',
#   'cobran',
#   'mas',
#   'impuestos',
#   'pagar',
#   'anterior',
#   'bienvenidos',
#   '4t'],
#  ['vamonos', 'cancun', 'vivapormexico'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['encontre',
#   'imagen',
#   'nuevo',
#   'abro',
#   'encuesta',
#   'comprobar',
#   'hacen',
#   'puto',
#   'caso'],
#  ['voy',
#   'sirvienta',
#   'haciendo',
#   'puto',
#   'quehacer',
#   'hermanos',
#   'si',
#   'viendo',
#   'videos',
#   'jugando',
#   'si',
#   'hago',
#   'entonces',
#   'pinches',
#   'limpia',
#   'puta',
#   'casa',
#   'mama'],
#  ['verano', 'lado', 'amigos'],
#  ['visita', 'pagina'],
#  ['ultimo',
#   'recurso',
#   'delincuente',
#   'pueblo',
#   'pasando',
#   'tan',
#   'mal',
#   'cara',
#   'mojigata',
#   'cristina',
#   'va',
#   'comprar',
#   'nadie',
#   'vez',
#   'vida',
#   'haganse',
#   'cargo',
#   'desastre',
#   'estan',
#   'dejando'],
#  ['mejores', 'vibras', 'quedaran', 'riquisimas', 'queremos', 'fotos'],
#  ['chairo', 'corrupto', 'arrastrado', 'ladron'],
#  ['kirus',
#   'concha',
#   'hermana',
#   'hijo',
#   'remil',
#   'puta',
#   'casi',
#   'agarran',
#   '3000',
#   'paros',
#   'basura',
#   'haces',
#   'twitteando',
#   'odio'],
#  ['hey',
#   'recibe',
#   'limosna',
#   'mensual',
#   'verdad',
#   'vale',
#   'brga',
#   'futuro',
#   'hijos',
#   'nietos',
#   'consciente',
#   'condenando',
#   'pais',
#   'jodido',
#   'aspiraciones',
#   'va',
#   'llevar',
#   'chngada',
#   'pvtas',
#   'moneditas',
#   'mames'],
#  ['aparece', 'puta'],
#  ['desnuda',
#   'folla',
#   'chacha',
#   'latina',
#   'tantas',
#   'chachas',
#   'latinas',
#   'dedican'],
#  ['trolls',
#   'bots',
#   'derecha',
#   'twitter',
#   'saben',
#   'madres',
#   'politica',
#   'solo',
#   'hablan',
#   'tonterias',
#   'verdadero',
#   'debate',
#   'monreal',
#   'munoz',
#   'ledo',
#   'dentro',
#   'izquierda',
#   'conservadores',
#   'sigan',
#   'haciendo',
#   'memes'],
#  ['siguen',
#   'llegando',
#   'mensajes',
#   'enlace',
#   'nota',
#   'jordan',
#   'rodriguez',
#   'puto',
#   'chile',
#   'mejor',
#   'dijo',
#   'vergatario',
#   'logro',
#   'apostillaran',
#   'cara',
#   'mmwbo',
#   'alla',
#   'hicieron'],
#  ['solo',
#   'estan',
#   'ayudando',
#   'arbitros',
#   'tambien',
#   'hablar',
#   'campana',
#   'puede',
#   'ser',
#   'tan',
#   'ciego',
#   'estan',
#   'cargando',
#   'clasificacion',
#   'europa'],
#  ['oremos',
#   'tal',
#   'cometio',
#   'error',
#   'ultima',
#   'entrevista',
#   'diciendo',
#   'virgen',
#   'maria',
#   'vientre',
#   'naciera',
#   'jesus',
#   '*hagame'],
#  ['ver',
#   'hijo',
#   'puta',
#   'madre',
#   'ustedes',
#   'escogimos',
#   'mierda',
#   'servicio',
#   'mejor',
#   'postor',
#   'propios',
#   'intereses',
#   'vamos',
#   'quitar',
#   'bola',
#   'mierdas'],
#  ['pidio',
#   'prestamo',
#   'mil',
#   'millones',
#   'dolares',
#   'banco',
#   'mundial',
#   'salud',
#   'secretaria',
#   'salud',
#   'quitaron',
#   '1',
#   '500',
#   'millones',
#   'pesos',
#   'sucursales',
#   'banco',
#   'bienestar',
#   'frente',
#   'transmision',
#   'energia',
#   '(',
#   'la',
#   'jornada'],
#  ['puto', 'asco', 'dia', 'cigarillo', 'dormir'],
#  ['virus',
#   'pepe',
#   'ruiz',
#   'presentador',
#   'canal',
#   '6',
#   'paz',
#   '(',
#   'descanse'],
#  ['parece',
#   'increible',
#   'tanta',
#   'gente',
#   'diga',
#   'zorra/vulgar/',
#   'doy',
#   'simplemente',
#   'hablar',
#   'varas',
#   'voy',
#   'ser',
#   'mojigata',
#   'infeliz',
#   'evitar',
#   'hablen',
#   'sexo',
#   'normal',
#   'ustedes',
#   'vulgaridad',
#   'maduren'],
#  ['texto',
#   'completo',
#   'realmente',
#   'nefasto',
#   'dice',
#   'sociedad',
#   'tratando',
#   'homosexualizarlo',
#   'conseguir',
#   'mujeres',
#   'veces',
#   'terminar',
#   'cubrir',
#   'necesidad',
#   'discurso',
#   'odio',
#   'enorme'],
#  ['ud',
#   'pregunte',
#   'precio',
#   'mocho',
#   'esponja',
#   'fregar',
#   'digan',
#   '300000bss',
#   'asombre',
#   'solo',
#   'recuerde',
#   'venezuela',
#   'gringosbueno'],
#  ['gente'],
#  ['veremos',
#   'dijo',
#   'ciego',
#   'aprovecho',
#   'espacio',
#   'hora',
#   'atacar',
#   'cuyo',
#   'programa',
#   'conduces',
#   'castaneda',
#   'camin',
#   'dan',
#   'asco',
#   'literal'],
#  ['2020', 'trae', 'asi'],
#  ['van',
#   '2',
#   'notas',
#   'grafico',
#   'cumple',
#   '33',
#   'lionel',
#   'messi',
#   'ilusion',
#   'imagen',
#   'campeon',
#   'sub',
#   '20',
#   'mayor',
#   '100x100',
#   'hice',
#   'leo',
#   'mientras',
#   'esperaba',
#   'ok',
#   'padre',
#   'entrevistarlo',
#   'mundial',
#   '2010',
#   '(',
#   'no',
#   'pudo'],
#  ['cuales',
#   'deberes',
#   'segun',
#   'diria',
#   'tiras',
#   'piedras',
#   'dieron',
#   'emchufle',
#   'ciego',
#   'ver',
#   'solo',
#   'parece',
#   'buenas',
#   'primera'],
#  ['puto',
#   'meo',
#   'ajajajajbsbwbsvevew',
#   'flipan',
#   'unas',
#   'galletas',
#   'parecidas',
#   'tmbn',
#   'fontaneda',
#   'llego',
#   'jsjsjsjs'],
#  ['mocho', 'jajaja', 'jajajajajaja'],
#  ['envivo',
#   '|',
#   'afectados',
#   '19-s',
#   'bloquean',
#   'tlalpan',
#   'presencia',
#   'policiaca',
#   'siguelo',
#   'periscope'],
#  ['amen'],
#  ['razones',
#   'creer',
#   'amlo',
#   'sido',
#   'mejor',
#   'presidente',
#   'mexico',
#   '-',
#   'amlo',
#   '-',
#   'familiar',
#   'amigo',
#   'amlo',
#   '-',
#   'nini',
#   'amlo',
#   'regala',
#   'dinero',
#   '-',
#   'funeraria',
#   'nunca',
#   'faltado',
#   'clientes',
#   'mandato',
#   '-',
#   'dejaron',
#   'caer',
#   'bebe',
#   '-',
#   'gusta',
#   'comer',
#   'pegamento'],
#  ['mames',
#   'ando',
#   'bien',
#   'jodido',
#   'dinero',
#   'traigo',
#   'also',
#   'mames',
#   'online',
#   'huevo',
#   'compro'],
#  ['kks', 'salio', 'mocho', 'pendejo', 'militarista'],
#  ['publico', 'tweets', 'encanta', 'coger', 'cojo', 'fff'],
#  ['correcto'],
#  ['acho', 'cojo', 'tiro', 'puente', 'cabron'],
#  ['corazon', 'mas', 'jodido'],
#  ['lopez',
#   'problema',
#   'salud',
#   'mental',
#   'grave',
#   'sospecho',
#   'mismo',
#   'ano',
#   'puede',
#   'quede',
#   'discapacitado',
#   'fallezca',
#   '(',
#   'abro',
#   'hilo'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['chairo',
#   'si',
#   'lopez',
#   'sabia',
#   'defenderlo',
#   'hace',
#   'pensar',
#   'sabe',
#   'existencia',
#   'defendera'],
#  ['creen',
#   'haran',
#   'respecto',
#   'cerraran',
#   'fronteras',
#   'mandaran',
#   'verga',
#   'dejaran',
#   'pasar',
#   'daran',
#   'atencion',
#   'medica',
#   'comida',
#   'trabajo',
#   'beca',
#   'nini-centroamerichango',
#   'hagan',
#   'apuestas'],
#  ['cunado',
#   'nunca',
#   'pagado',
#   'impuestos',
#   'nini',
#   '54',
#   'anios',
#   'busca',
#   'chamba',
#   'supervisor'],
#  ['si', 'tambien', 'puto', 'sistema', 'mal'],
#  ['jajajajjajajajajaaaaaaa',
#   'hijo',
#   'puta',
#   'hijo',
#   'puta',
#   'ahora',
#   'comico',
#   'h'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['lily',
#   'timothee',
#   'tiraban',
#   'hate',
#   'ahora',
#   'eiza',
#   'anda',
#   'tiran',
#   'hate',
#   'aman',
#   'lily',
#   'puta',
#   'venenosas'],
#  ['tema', 'reiniciar', 'ps4', 'va', 'tan', 'puto', 'mal'],
#  ['busqueda',
#   'alternativas',
#   'acercar',
#   'producto',
#   'clientes',
#   'colectivo',
#   'acopio',
#   'ciegodeavila',
#   'listo',
#   'prestar',
#   'servicios',
#   'primer',
#   'bici-agro',
#   'enterese'],
#  ['vivo',
#   'heraldo',
#   'jalisco',
#   'platicamos',
#   'golf',
#   'tenis',
#   'beisbol',
#   'mlb',
#   'liga',
#   'mx',
#   'mundo',
#   'nini',
#   'mas'],
#  ['sigueme', 'puto'],
#  ['rumbo', 'semaforo', 'rojo', 'sigamos', 'medidas', 'preventivas'],
#  ['mama',
#   'morena',
#   'papa',
#   'guero',
#   'ojos',
#   'color',
#   'primera',
#   'hija',
#   'salio',
#   'guerita',
#   'ojos',
#   'claro',
#   'abuela',
#   'acaba',
#   'subir',
#   'video',
#   'presentan',
#   'nuevo',
#   'hermanito',
#   'nena',
#   'diciendole',
#   'salio',
#   'guerito',
#   'diria',
#   'master',
#   'valores',
#   'maman',
#   'casa'],
#  ['wey',
#   'pues',
#   'vivimos',
#   'pais',
#   'lleno',
#   'indigenas',
#   'profesionistas',
#   'mexicanos',
#   'deberiamos',
#   'saber',
#   'idiomas',
#   'indigenas',
#   'extranjeros',
#   'gusta',
#   'aceptar',
#   'origen',
#   'tener',
#   'conciencia',
#   'historica',
#   'hace',
#   'chairo',
#   'falta',
#   'empatia',
#   'si',
#   'hace',
#   'discriminar'],
#  ['jajaja',
#   'nope',
#   'cuenta',
#   'solo',
#   'disfruto',
#   'ver',
#   'reacciona',
#   'chairo',
#   'mas',
#   'hahahaha'],
#  ['gol',
#   'mejor',
#   'futbolista',
#   'historia',
#   'mexico',
#   'hijos',
#   'puta',
#   'madre',
#   'raullando'],
#  ['ud',
#   'pregunte',
#   'precio',
#   'mocho',
#   'esponja',
#   'fregar',
#   'digan',
#   '300000bss',
#   'asombre',
#   'solo',
#   'recuerde',
#   'venezuela',
#   'gringosbueno'],
#  ['entramos',
#   'etapa',
#   'casi',
#   'imposible',
#   'debatir',
#   'preferencia',
#   'candidato',
#   'vs',
#   'punto',
#   'vista',
#   'propuestas',
#   'evaluacion',
#   'plan',
#   'gobierno',
#   'epoca',
#   'fanatismo',
#   'ciego',
#   'argumento'],
#  ['oye',
#   'pendejo',
#   'alguna',
#   'vez',
#   'trabajado',
#   'solamente',
#   'dedicado',
#   'vivir',
#   'beca',
#   'nini'],
#  ['jajajajajjja', 'cago', 'puta'],
#  ['solo',
#   'vengo',
#   'recordarles',
#   'interior',
#   'pais',
#   'puta',
#   'idea',
#   'diferencia',
#   'caba',
#   'amba',
#   'capital',
#   'provincia'],
#  ['siempre', 'ando', 'perdiendo', 'lentes', 'bn', 'perrones'],
#  ['asi',
#   'huevo',
#   'animo',
#   'regresaras',
#   'hacernos',
#   'campeones',
#   'clausura',
#   '2021',
#   'webooooo',
#   'si',
#   'mocho',
#   'idem'],
#  ['primera', 'vez', 'tiempo', 'uso', 'nombre', 'juego', 'valorant', 'mocho'],
#  ['17',
#   'marzo',
#   'pedro',
#   'sanchez',
#   'dijo',
#   'textualmente',
#   'crisis',
#   'hoy',
#   'fmi',
#   'coloca',
#   'espana',
#   'cabeza',
#   'hundimiento',
#   'economico',
#   'presidente',
#   'economia',
#   'puto',
#   'lince',
#   'oraculo'],
#  ['jajajjaaj', 'chales'],
#  ['jajajaja',
#   'chairo',
#   'mas',
#   'mejor',
#   'publica',
#   'logros',
#   'si',
#   'alguno',
#   'vez',
#   'solo',
#   'echar',
#   'porras'],
#  ['via',
#   'jajajaj',
#   'cnn',
#   'tenia',
#   'montado',
#   'circo',
#   'jodido',
#   'circo',
#   'xq',
#   'hablan',
#   'muneco',
#   'aparecio',
#   'ropa',
#   'policia',
#   'miami',
#   'colgado',
#   'puente',
#   'si',
#   'existio',
#   'verdad',
#   'crimen',
#   'odio'],
#  ['confirmen',
#   'si',
#   'ustedes',
#   'tambien',
#   'calculan',
#   'cuantas',
#   'horas',
#   'van',
#   'dormir',
#   'dormirse'],
#  ['extrano',
#   'guanajuato',
#   'clima',
#   'salir',
#   'cafecito',
#   'amigos',
#   'regresar',
#   'puta',
#   'madre',
#   'pedo',
#   '[',
#   ']'],
#  ['buen',
#   'dia',
#   'envian',
#   'vecinos',
#   'informacion',
#   'favor',
#   'perrito',
#   'encuentre',
#   'duenos',
#   'mil',
#   'gracias'],
#  ['buen', 'ingles'],
#  ['doctor', 'fracasado', 'hijo', 'puta', 'mas'],
#  ['preguntan',
#   'presidente',
#   'opina',
#   'proyeccion',
#   'fondo',
#   'monetario',
#   'internacional',
#   '-105',
#   '%',
#   'mexico',
#   'contesta',
#   'va',
#   'pesimista',
#   'solamente',
#   'dedicaban',
#   'robar',
#   'pueden',
#   'dice',
#   'cantar',
#   'gracias',
#   'vida',
#   'dado'],
#  ['quince',
#   'anos',
#   'fatales',
#   'arroz',
#   'bacalao',
#   'tocino',
#   'quemao',
#   'manteca',
#   'tamales',
#   'acabaron',
#   'panales',
#   'crema',
#   'azucarada',
#   'papitas',
#   'rebozadas',
#   'gustan',
#   'dice',
#   'hijo',
#   'puta',
#   'cuba',
#   'falta'],
#  ['asi', 'prd', 'financia', 'dinero', 'crimen', 'organizado'],
#  ['quede',
#   'constancia',
#   'declaracion',
#   'tipo',
#   'entendimiento',
#   'acerca',
#   'democracia',
#   'separacion',
#   'poderes',
#   'acaso',
#   'creen',
#   'chairo',
#   'enloquecido',
#   'persona',
#   'ser',
#   'considerado',
#   'miembro',
#   'comite',
#   'tecnico'],
#  ['neta', 'puto', 'coraje', 'gente'],
#  ['acabe',
#   'semestre',
#   'dormir',
#   'puto',
#   'dia',
#   'todas',
#   'formas',
#   'duermo',
#   'dia',
#   'bien',
#   'preocupada',
#   'mamen',
#   '('],
#  ['si',
#   'supieran',
#   'favorito',
#   'ser',
#   'insultado',
#   'chaira',
#   'gacha',
#   'mantenida',
#   'chairo',
#   'idem'],
#  ['propongo',
#   'jose',
#   'gregorio',
#   'pase',
#   'beato',
#   'santo',
#   'conocido',
#   'san',
#   'goyo',
#   'ojo',
#   'san',
#   'cocho',
#   'sugiere',
#   'vecino',
#   'santurron',
#   'cervecero'],
#  ['alguien',
#   'sabe',
#   'cuanto',
#   'recibe',
#   'beca',
#   'joven',
#   'destruyendo',
#   'futuro',
#   'edad',
#   'nini'],
#  ['fucking', 'amor', 'ciego'],
#  ['mira',
#   'cojo',
#   'esposa',
#   'pinche',
#   'cornudo',
#   '-',
#   '-',
#   'estre',
#   'mensaje',
#   'envio',
#   'corneador',
#   'esposa',
#   'si',
#   'quieres',
#   'cogerme',
#   'puta'],
#  ['contestan',
#   'puto',
#   'wpp',
#   'si',
#   'disponible',
#   'si',
#   'listo',
#   'responde',
#   'explica',
#   'si',
#   'dejas',
#   'responder',
#   'das',
#   'pie',
#   'piense',
#   'peor'],
#  ['chinga', 'madre', 'pinche', 'viejito', 'pendejo'],
#  ['verga',
#   'comentario',
#   'dirigido',
#   'eiza',
#   'pq',
#   'hace',
#   'puto',
#   'desmadre',
#   'body',
#   'shaming'],
#  ['solo',
#   'vengo',
#   'recordarles',
#   'interior',
#   'pais',
#   'puta',
#   'idea',
#   'diferencia',
#   'caba',
#   'amba',
#   'capital',
#   'provincia'],
#  ['creo',
#   'alli',
#   'nace',
#   'complejos',
#   'amigos',
#   'papa',
#   'salazar',
#   'mocho',
#   'quijada',
#   'negro',
#   'espinoza'],
#  ['parece',
#   'increible',
#   'tanta',
#   'gente',
#   'diga',
#   'zorra/vulgar/',
#   'doy',
#   'simplemente',
#   'hablar',
#   'varas',
#   'voy',
#   'ser',
#   'mojigata',
#   'infeliz',
#   'evitar',
#   'hablen',
#   'sexo',
#   'normal',
#   'ustedes',
#   'vulgaridad',
#   'maduren'],
#  ['solo',
#   'vengo',
#   'recordarles',
#   'interior',
#   'pais',
#   'puta',
#   'idea',
#   'diferencia',
#   'caba',
#   'amba',
#   'capital',
#   'provincia'],
#  ['malo',
#   'fifa',
#   'tambien',
#   'ciego',
#   'vaya',
#   'explica',
#   'muchas',
#   'cosas',
#   'casemiro',
#   'dos',
#   'asi',
#   'cada'],
#  ['pinche',
#   'nino',
#   'mazapan',
#   'deja',
#   'ser',
#   'tan',
#   'delicadito',
#   'delicadito',
#   'andas',
#   'inventando',
#   'cosas',
#   'amenaza',
#   'abusando',
#   'condicion',
#   'jajaja',
#   'vete',
#   'descular',
#   'hormigas',
#   'entretengas',
#   '(',
#   'ahora',
#   'di',
#   'lenguaje',
#   'atenta',
#   'animales',
#   'jajaja'],
#  ['desaparecidosoij', 'persona', 'fotografia', 'encuentra', 'desaparecida'],
#  ['pueblo',
#   'gusta',
#   'populismo',
#   '(',
#   'mocho',
#   'clientelismo',
#   'paternalismo',
#   'poca',
#   'preparacion',
#   'academica',
#   'parecer',
#   'sido',
#   'creado',
#   'despues',
#   'invacion',
#   '89',
#   'protestas',
#   'populares',
#   'disminuyeron',
#   'satanizaron',
#   'jovenes',
#   'ahora',
#   'limbo',
#   'accionan'],
#  ['pues',
#   'si',
#   'imaginense',
#   'aparezca',
#   'noche',
#   'votaste',
#   'puto',
#   'iba',
#   'cojer',
#   'si'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['respeto',
#   'respetuoso',
#   'senora',
#   'cree',
#   'mocho',
#   'enganado',
#   'siempre',
#   'salen',
#   'medios',
#   'comunicacion',
#   'dando',
#   'declaraciones',
#   'mas',
#   'desgastan',
#   'debieran',
#   'retirarse',
#   'irse',
#   'pais'],
#  ['escuchado',
#   'todas',
#   'formaciones',
#   'politicas',
#   'hecho',
#   'incluido',
#   'propuestas',
#   'ademas',
#   'incluido',
#   'tambien',
#   'profesionales',
#   'mutualistas',
#   'dentro',
#   'beneficiarios',
#   'gracias',
#   'union'],
#  ['solo',
#   'vengo',
#   'recordarles',
#   'interior',
#   'pais',
#   'puta',
#   'idea',
#   'diferencia',
#   'caba',
#   'amba',
#   'capital',
#   'provincia'],
#  ['paso', 'horas', 'hablando'],
#  ['pobre',
#   'netcenter',
#   'chairo',
#   'mas',
#   'trato',
#   'poner',
#   'tendencia',
#   'viene',
#   'pescado',
#   'ruiz',
#   'video',
#   'opaca',
#   'va',
#   'ganando',
#   'net',
#   'paul',
#   'anria'],
#  ['simon',
#   'entambarlo',
#   'ponga',
#   'trabajar',
#   'amo',
#   'pinche',
#   'chairo',
#   'croquetero'],
#  ['frybo', 'jodido', 'superarlo'],
#  ['gol',
#   'mejor',
#   'futbolista',
#   'historia',
#   'mexico',
#   'hijos',
#   'puta',
#   'madre',
#   'raullando'],
#  ['tan', 'punetas', 'amigos', 'dieron', 'chamba', 'nini', 'cuasipolitica'],
#  ['come',
#   'mucha',
#   'mierda',
#   'arenero',
#   'hijo',
#   'puta',
#   'solo',
#   'estorbar',
#   'sirven'],
#  ['ves',
#   'valiste',
#   'madre',
#   'elecciones',
#   'proximo',
#   'ano',
#   'inicias',
#   'plantar',
#   'duda',
#   'pongase',
#   'trabajar',
#   'pinche',
#   'viejito'],
#  ['madre', 'mocho', 'derecha', 'lista', 'aparece', '000000001', 'matarife'],
#  ['estimado',
#   'si',
#   'rentable',
#   'adquieren',
#   'cisneronadie',
#   'compra',
#   'perder',
#   'extrano',
#   'repuestael',
#   'mejor',
#   'equipo',
#   'fullllll',
#   'venta',
#   'cero',
#   'gananciasese',
#   'cuento',
#   'quedo',
#   'mocho'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['muchas',
#   'gracias',
#   'senalar',
#   'padecimientos',
#   'mentales',
#   'pagame',
#   'terapia',
#   'trata',
#   'ser',
#   'menos',
#   'pendejo',
#   'puta',
#   'madre'],
#  ['peor',
#   'ciego',
#   'quiere',
#   'aplica',
#   'cualquier',
#   'momento',
#   'cualquier',
#   'circunstancia',
#   'vida'],
#  ['hago', 'creo', 'maricon'],
#  ['iba', 'ser', 'diesel', 'pinche', 'viejito', 'van', 'cabras', 'gacho'],
#  ['carpintero',
#   'necesito',
#   'trabajar',
#   'ayudar',
#   'hermano',
#   'cancer',
#   'hace',
#   'falta',
#   'medicamento',
#   'docetaxel',
#   '80',
#   'mg',
#   'ampollas',
#   'pueda',
#   'ayudar',
#   'si',
#   'alguien',
#   'medicamento',
#   'pueda',
#   'donar',
#   '0412-4486870',
#   'gracias',
#   'dios',
#   'bendiga'],
#  ['desarrollo',
#   'minindustrias',
#   'cuba',
#   'sido',
#   'paso',
#   'decisivo',
#   'desarrollo',
#   'economia',
#   'media',
#   'luna',
#   'ciegodeavila',
#   'ejemplo',
#   'cuanto',
#   'logra',
#   'abre',
#   'paso',
#   'nuevas',
#   'gestiones',
#   'produccion',
#   'pormenores'],
#  ['puta', 'idea', 'haciendo'],
#  ['confirmen',
#   'si',
#   'ustedes',
#   'tambien',
#   'calculan',
#   'cuantas',
#   'horas',
#   'van',
#   'dormir',
#   'dormirse'],
#  ['jajajajajajajajaja',
#   'nadie',
#   'dijo',
#   'aqui',
#   'pendejo',
#   'tomandome',
#   'cuenta',
#   'horas',
#   'jajajajajaja',
#   'pobre',
#   'jodido',
#   'supera',
#   'cabron',
#   'lastima',
#   'caminar',
#   'bien',
#   'atravezada',
#   'vrg',
#   'messi',
#   'adentro',
#   'jajajajajaja'],
#  ['prensa',
#   'dominica',
#   'barrio',
#   'puede',
#   'ser',
#   'solo',
#   'sector',
#   'bien',
#   'jodido',
#   'tratennos',
#   'decencia',
#   'estudiamos',
#   'aqui'],
#  ['ojoaldato',
#   'cifras',
#   'van',
#   'aumento',
#   'publico',
#   'activo',
#   'bomba',
#   'tiempo',
#   'diputados',
#   'hicieron',
#   'mecha',
#   'mas',
#   'bomba',
#   'mas',
#   'grande',
#   'solo',
#   'ciego',
#   'da',
#   'cuenta',
#   'nayib',
#   'hizo',
#   'pudo'],
#  ['quintero',
#   'propio',
#   'dejo',
#   'meter',
#   'ganso',
#   'ciego',
#   'perro',
#   'hijueputa',
#   'ome',
#   'si',
#   'lok'],
#  ['jajajaja', 'bieja', 'puta'],
#  ['respondi', 'puta'],
#  ['chairo'],
#  ['guanajuato',
#   'mocho',
#   'gran',
#   'paso',
#   'logro',
#   'enorme',
#   'solo',
#   'hace',
#   'falta',
#   'ver',
#   'carita',
#   'emiliano',
#   'ver',
#   'felicidad'],
#  ['va',
#   'sola',
#   'guapa',
#   'inteligente',
#   'combinacion',
#   'fatalpara',
#   'idiota',
#   'narcisista',
#   'cerebro',
#   'nuez',
#   'nini',
#   'baston',
#   'chupamedias'],
#  ['zona',
#   'militar',
#   'ine',
#   'ah',
#   'envio',
#   'gp',
#   'mensaje',
#   'chairo',
#   'pablo',
#   'califica',
#   'ser',
#   'cualquier',
#   'cosa',
#   'signifique'],
#  ['contesto',
#   'hilandera',
#   'hilaba',
#   'dia',
#   'vio',
#   'hilandera',
#   'hombre',
#   'ciego',
#   'lloraba',
#   'espesa',
#   'venda',
#   'atravesada',
#   'lagrimas',
#   'gota',
#   'cristalina',
#   'cada',
#   'ojo',
#   'manaba',
#   'hombre',
#   'dijo',
#   'hilandera',
#   'mirando',
#   'cara',
#   'bien',
#   've',
#   'mundo'],
#  ['mas', 'mocho', 'estare', 're', 'loca', 'triste_'],
#  ['derechairo', 'ardido'],
#  ['chavoruco',
#   'twitter',
#   'llevas',
#   'mas',
#   'tiempo',
#   'aqui',
#   'pense',
#   'conocias'],
#  ['puta', 'mierda', 'final', 'nomames', 'puta', 'mamada'],
#  ['ojoaldato',
#   'cifras',
#   'van',
#   'aumento',
#   'publico',
#   'activo',
#   'bomba',
#   'tiempo',
#   'diputados',
#   'hicieron',
#   'mecha',
#   'mas',
#   'bomba',
#   'mas',
#   'grande',
#   'solo',
#   'ciego',
#   'da',
#   'cuenta',
#   'nayib',
#   'hizo',
#   'pudo'],
#  ['spainrp', 'siempre', 'carajo'],
#  ['pinche', 'viejito', 'pendejo', 'payaso', 'peor', 'cepillin'],
#  ['micronegocios',
#   'representan',
#   'esencial',
#   'economia',
#   'pais',
#   'apoyamos',
#   'creditos',
#   'salgan',
#   'adelante',
#   'fincomun',
#   'sisepuede'],
#  ['manera', 'amedrentar'],
#  ['cuero', 'naco'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['traigo', 'ganas', 'puta', 'madre', 'dia', 'puedes'],
#  ['pension',
#   'salud',
#   'necesidades',
#   'pension',
#   'digna',
#   'atencion',
#   'salud',
#   '100',
#   '%',
#   'clinicas',
#   'mendigando',
#   'atiendan',
#   'tener',
#   'politico',
#   'atiendan'],
#  ['vida', 'hace', 'falta', 'guerito', 'toxico'],
#  ['tumba',
#   'muchas',
#   'felicidades',
#   'dios',
#   'mande',
#   'muchas',
#   'bendiciones',
#   'ayude',
#   'seguir',
#   'levantando',
#   'voz',
#   'apoyamos',
#   'proyecto',
#   'mastumbamenos4t'],
#  ['hey',
#   'recibe',
#   'limosna',
#   'mensual',
#   'verdad',
#   'vale',
#   'brga',
#   'futuro',
#   'hijos',
#   'nietos',
#   'consciente',
#   'condenando',
#   'pais',
#   'jodido',
#   'aspiraciones',
#   'va',
#   'llevar',
#   'chngada',
#   'pvtas',
#   'moneditas',
#   'mames'],
#  ['mastemprano',
#   '|',
#   'oms',
#   'publicado',
#   'especificaciones',
#   'tecnicas',
#   'diseno',
#   'equipos',
#   'generan',
#   'propio',
#   'oxigeno',
#   'concentrado',
#   'grandes',
#   'cantidades',
#   'asi',
#   'orientacion',
#   'paises',
#   'fuentes',
#   'distribucion',
#   'oxigeno',
#   'caraboboesvictoriapatria'],
#  ['salio',
#   'peine',
#   'revelan',
#   'mano',
#   'derecha',
#   'silvano',
#   'aureoles',
#   'dueno',
#   'latinus',
#   'programa',
#   'loret',
#   'mola'],
#  ['unica',
#   'respuesta',
#   'chairo',
#   'iletrado',
#   'come',
#   'croquetas',
#   'hablar',
#   'calderon',
#   'leido',
#   'libro',
#   'vaquero',
#   'mama',
#   'limpia',
#   'trasero'],
#  ['coronavirus',
#   'maricon',
#   'asi',
#   'decia',
#   'pepe',
#   'ruiz',
#   'supuesto',
#   'cronista',
#   'canal',
#   '6',
#   'desafiaba',
#   'covid',
#   '19',
#   'comparandolo',
#   'oposicion',
#   'aseguraba',
#   'solo',
#   'necesitaba',
#   'hacer',
#   'gargaras',
#   'limon',
#   '*y',
#   'ahora'],
#  ['mocho', 'huevo', 'puto'],
#  ['comiendo',
#   'bien',
#   'tampoco',
#   'durmiendo',
#   'bien',
#   'menos',
#   'haciendo',
#   'cosas',
#   'bien',
#   'simplemente',
#   'funcionando',
#   'bien'],
#  ['si', 'pones', 'foto', 'perfil', 'mocho', 'teta'],
#  ['ay',
#   'ridiculo',
#   'persinado',
#   'idiotita',
#   'ten',
#   'dos',
#   'gramos',
#   'criterio'],
#  ['desarrollo',
#   'minindustrias',
#   'cuba',
#   'sido',
#   'paso',
#   'decisivo',
#   'desarrollo',
#   'economia',
#   'media',
#   'luna',
#   'ciegodeavila',
#   'ejemplo',
#   'cuanto',
#   'logra',
#   'abre',
#   'paso',
#   'nuevas',
#   'gestiones',
#   'produccion',
#   'pormenores'],
#  ['amigos',
#   'triste',
#   'noticia',
#   'guerito',
#   'descansa',
#   'final',
#   'sufriendo',
#   'pudimos',
#   'seguir',
#   'alargando',
#   'mas',
#   'agonia',
#   'aun',
#   'canalizado',
#   'salud',
#   'seguia',
#   'empeorando',
#   'asi',
#   'decidimos',
#   'mejor',
#   'hacerlo',
#   'sufrir',
#   'mas'],
#  ['nini', 'recogimos', 'parque', 'adoptamos'],
#  ['jajaja', 'va', 'mal', 'leen', 'dan', 'cuenta', 'jodido', 'pais'],
#  ['manga', 'hijos', 'puta', 'votaron', 'eh', 'hijos', 'remil', 'puta'],
#  ['onda',
#   'chairo',
#   'depravadin',
#   'sigues',
#   'perdido',
#   'iztapalapa',
#   'x',
#   'sismo'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['bayanse',
#   'cagar',
#   'uds',
#   'hacen',
#   'mas',
#   'espionaje',
#   'extorsion',
#   'q',
#   'culquiera',
#   'extorsionan',
#   'pudiendo',
#   'coima',
#   'xa',
#   'poder',
#   'ejercer',
#   'actividad',
#   'rubro',
#   'cautivo',
#   'asociados',
#   'q',
#   'pueda',
#   'elegir',
#   'puto',
#   'gremio',
#   'q',
#   'unico',
#   'q',
#   'mantiene',
#   'arcas',
#   'xacique'],
#  ['pareces',
#   'nino',
#   'chiquito',
#   'deja',
#   'robar',
#   'haces',
#   'desviar',
#   'robos',
#   'esposa',
#   'personas',
#   'tambien',
#   'cola',
#   'pise'],
#  ['lopez',
#   'problema',
#   'salud',
#   'mental',
#   'grave',
#   'sospecho',
#   'mismo',
#   'ano',
#   'puede',
#   'quede',
#   'discapacitado',
#   'fallezca',
#   '(',
#   'abro',
#   'hilo'],
#  ['wey', 'usaba', 'zurda', 'subirse', 'camion', 'puto', 'perro', 'golazo'],
#  ['quede',
#   'constancia',
#   'declaracion',
#   'tipo',
#   'entendimiento',
#   'acerca',
#   'democracia',
#   'separacion',
#   'poderes',
#   'acaso',
#   'creen',
#   'chairo',
#   'enloquecido',
#   'persona',
#   'ser',
#   'considerado',
#   'miembro',
#   'comite',
#   'tecnico'],
#  ['ver',
#   'hipocrita',
#   'mojigata',
#   'tiras',
#   'piedra',
#   'escondes',
#   'mano',
#   'igual',
#   'marido'],
#  ['mmmmm',
#   'si',
#   'twit',
#   'mas',
#   'pedo',
#   'viene',
#   'alguien',
#   'morena',
#   'mocho',
#   'asustan',
#   'dictadores'],
#  ['alguien',
#   'sabe',
#   'cuanto',
#   'recibe',
#   'beca',
#   'joven',
#   'destruyendo',
#   'futuro',
#   'edad',
#   'nini'],
#  ['entendible',
#   'negar',
#   'exito',
#   'ver',
#   'privilegio',
#   'existente',
#   'mexico',
#   'parece',
#   'ingenuo',
#   'siendo',
#   'moreno',
#   'beneficiado',
#   'siendo',
#   'blanco',
#   'mas',
#   'recordemos',
#   'mexico',
#   'ser',
#   'guerito',
#   'profesion',
#   'saludos'],
#  ['virus',
#   'maricon',
#   'fallece',
#   'polemico',
#   'cronista',
#   'canal',
#   '6',
#   'pepe',
#   'ruiz'],
#  ['cuenta',
#   'dizque',
#   'unico',
#   'habla',
#   'maravillas',
#   'proyecto',
#   'maneja',
#   'cuenta',
#   'basta',
#   'solo',
#   'echar',
#   'vistazo',
#   'comentarios'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['oficialmente', 'damos', 'bienvenida'],
#  ['favor',
#   'ayudan',
#   'sustrajeron',
#   'salir',
#   'domicilio',
#   'villahermosatabasco',
#   'companerita',
#   'hijo'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['4',
#   'primeras',
#   'plagas',
#   'faraon',
#   'socialista',
#   'nini',
#   'huevon',
#   'alias'],
#  ['totalmente', 'enfermo', 'amor', 'pr', 'bos', 'puta'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['|santiago|',
#   'noche',
#   'ayer',
#   'manana',
#   'hoy',
#   'entregando',
#   'raciones',
#   'alimenticias',
#   'x',
#   'sector',
#   'villa',
#   'jagua',
#   'zona',
#   'sur',
#   'comunidades',
#   'cocos',
#   'arroyos',
#   '31',
#   'municipio',
#   'punal',
#   'plansocialrd'],
#  ['ladron',
#   'siempre',
#   'ingenia',
#   'seguir',
#   'robando',
#   'enganando',
#   'tranzando',
#   'cuello',
#   'blanco',
#   'cola',
#   'roja',
#   'ratas',
#   'naturaleza',
#   'gusta',
#   'digan',
#   'senores'],
#  ['onvres',
#   'tipo',
#   'si',
#   'gusto',
#   'comentario',
#   '-misogino',
#   'machista',
#   'jodido',
#   'ofendiendo',
#   'mujer',
#   'nomas',
#   'ser',
#   'mujer-',
#   'pues',
#   'des',
#   'like',
#   'sigue',
#   'camino'],
#  ['maricon', 'seguro', 'igual', 'zoofilico', 'asno'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['wey', 'bien', 'mocho', 'escribir', 'mms'],
#  ['manana',
#   'van',
#   'comenzar',
#   'callar',
#   'dia',
#   'sera',
#   'fiesta',
#   'cachurecos',
#   'hijos',
#   'puta',
#   'buen',
#   'dia'],
#  ['leo',
#   'creo',
#   'veo',
#   'quedo',
#   'ciego',
#   'verdad',
#   'pensaste',
#   'presentas',
#   'sono',
#   'bien',
#   'cabeza',
#   'menor',
#   'idea',
#   'escribiste',
#   'recomiendo',
#   'tratados',
#   'derechos',
#   'humanos',
#   'encuentren',
#   'ideas'],
#  ['quedan', 'calipos', 'ninio', 'solo', 'mosibustion'],
#  ['sabado',
#   'wey',
#   'pedo',
#   'dice',
#   'callate',
#   'pinche',
#   'pobre',
#   'si',
#   'dieron',
#   'educacion',
#   'decia',
#   'si',
#   'mientras',
#   'ponia',
#   'cinturon',
#   'seguridad',
#   'camioneta',
#   'novia',
#   'decia',
#   'dandole',
#   'iphone',
#   '11',
#   'saco',
#   'pagos'],
#  ['na', 'acaba', 'llegar', '60', 'millones', 'views', 'youtube'],
#  ['covid',
#   'viaja',
#   'carro',
#   'municipio',
#   'gente',
#   'puede',
#   'salir',
#   'entrar',
#   'carro',
#   'pie',
#   'si'],
#  ['ademas',
#   'ser',
#   'mocho',
#   'mente',
#   'deberias',
#   'ser',
#   'mocho',
#   'dedos',
#   'escribas',
#   'imbecilidades'],
#  ['cojo', 'lucha', 'nadie'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['familiar',
#   'escipion',
#   'africano',
#   '>',
#   '>',
#   'nombre',
#   'publio',
#   'cornelio',
#   '(',
#   '236-183',
#   'ac',
#   'gran',
#   'general',
#   'antigua',
#   'roma',
#   'apellido',
#   'familiar',
#   'adopto',
#   'abuelo',
#   'ciego',
#   'siempre',
#   'apoyaba',
#   'hijo',
#   'baston',
#   'latin',
#   'sirvio',
#   'idea',
#   'historia'],
#  ['agencia',
#   'publicidad',
#   'comunicacion',
#   'mala',
#   'tambien',
#   'fotografo',
#   'editor',
#   'pesimo',
#   'pie',
#   'presidente',
#   'mocho',
#   'pusieron',
#   'enfermera',
#   'china',
#   'neta'],
#  ['va',
#   'va',
#   'osea',
#   'hace',
#   'pinche',
#   'viejito',
#   'quiera',
#   'pensar',
#   'comunidades',
#   'mira',
#   'primero',
#   'pueblo'],
#  ['puta', 'bestia'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['asi', 'solo', 'ves', 'medios', 'chairo', 'dicen'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['puta', 'madre', 's'],
#  ['mas', 'puta', 'idea', 'renato', 'silva', 'erviti', 'dario'],
#  ['siempre',
#   'derechos',
#   'mujeres',
#   'ninas',
#   'violados',
#   'colombia',
#   'dia',
#   'aproximadamente',
#   'violan',
#   '55',
#   'ninas',
#   'adolescentes',
#   'tipo',
#   'hombres',
#   'crian',
#   'pais',
#   'marchitos',
#   'luego',
#   'mujer',
#   'indigna',
#   'reclama',
#   'feminazi'],
#  ['telerisa',
#   'fascina',
#   'mantiene',
#   'mocho',
#   'homofobo',
#   'racista',
#   'clasista',
#   'esteban',
#   'arce',
#   'arroban',
#   'bloqueo'],
#  ['facil',
#   'hablar',
#   'argumentos',
#   'si',
#   'piensas',
#   'persona',
#   'lado',
#   'informada',
#   'pasa',
#   'pais',
#   'aqui',
#   'caso',
#   'estimado'],
#  ['levantarse',
#   '6',
#   'tan',
#   'amebas',
#   'borregos',
#   'solo',
#   'soltais',
#   'gilipolleces',
#   'si',
#   'si',
#   'hicieras',
#   'necio',
#   'jajajaja',
#   'vamos',
#   'jodido',
#   'votan',
#   'nini',
#   'hablan',
#   'presentador',
#   'lleva',
#   'toda',
#   'vida',
#   'presentando',
#   'belen',
#   'esteban',
#   'nueva',
#   'referencia'],
#  ['tenia', 'ser', 'panista', 'mocho'],
#  ['hoy',
#   'cita',
#   'bebe',
#   'posicion',
#   'pedi',
#   'juicioso',
#   'acomodara',
#   'mami',
#   'pueda',
#   'parir',
#   'solo',
#   'espero',
#   'vuelva',
#   'cambiar',
#   'posicion',
#   'mas',
#   'ahora',
#   'carnavales',
#   'arma',
#   'adentro'],
#  ['ojoaldato',
#   'cifras',
#   'van',
#   'aumento',
#   'publico',
#   'activo',
#   'bomba',
#   'tiempo',
#   'diputados',
#   'hicieron',
#   'mecha',
#   'mas',
#   'bomba',
#   'mas',
#   'grande',
#   'solo',
#   'ciego',
#   'da',
#   'cuenta',
#   'nayib',
#   'hizo',
#   'pudo'],
#  ['mexicanos', 'presidente', 'jodido', 'chiste'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['vean',
#   'virus',
#   'ningun',
#   'funcionan',
#   'gargaras',
#   'agua',
#   'sal',
#   'banos',
#   'hojas',
#   'eucalipto'],
#  ['venezuela',
#   'sino',
#   'sirves',
#   'util',
#   'metes',
# ...
#  ['edad',
#   'podemos',
#   'jugar',
#   'sentimientos',
#   'demas',
#   'maduros',
#   'sabemos',
#   'queremos',
#   'queremos'],
#  ['inmunidad',
#   'farsa',
#   'gatell',
#   'cada',
#   'vez',
#   'decepcionas',
#   'mas',
#   'si',
#   'usaras',
#   'ciencia',
#   'darias',
#   'cuenta',
#   'realidad',
#   'dista',
#   'numeros',
#   'pandemia',
#   'obedece',
#   'reglas',
#   'sigues',
#   'ciego',
#   'dirigiendo',
#   'ciegos',
#   'abismo'],
#  ['igual', 'siempre', 'veo', 'mal', 'preocupais', 'maricon'],
#  ['ejercitoviolador',
#   'precisamente',
#   'ayer',
#   'vi',
#   'pelicula',
#   'hija',
#   'general',
#   'trata',
#   'mismo',
#   'tema',
#   'instituciones',
#   'malas',
#   'personas',
#   'enlodan',
#   'labor',
#   'tema',
#   'amplio',
#   'jodido'],
#  ['hoy', 'segui', 'ig', 'lt3', 'amo', 'dinamicas'],
#  ['onda',
#   'mina',
#   'mira',
#   'encima',
#   'hombro',
#   'jajaa',
#   'pelotudo',
#   'pedo',
#   'pienso',
#   'ayudar',
#   '('],
#  ['digamos',
#   'presidente',
#   'verdad',
#   'ciego',
#   'sordo',
#   'mudo',
#   'violencia',
#   'pandemia',
#   'economia',
#   'asi',
#   'q',
#   'disculpe',
#   'si',
#   'opine',
#   'politico',
#   'mayoria',
#   'camaras',
#   'interese'],
#  ['sigan',
#   'ignorantes',
#   'estupidos',
#   'dice',
#   'sabiduria',
#   'popular',
#   'peor',
#   'ciego',
#   'quiere',
#   'ver',
#   'peor',
#   'sordo',
#   'quiere',
#   'malo',
#   'gente',
#   'q',
#   'muere',
#   'irresponsabilidad'],
#  ['peor', 'ciego', 'quiere', 'ver', 'asi'],
#  ['pues',
#   'genera',
#   'suspicacia',
#   'margen',
#   'variacion',
#   'abinader',
#   'munimo',
#   'diferencia',
#   'demas',
#   'peor',
#   'ciego',
#   'quiere',
#   'ver'],
#  ['lopez',
#   'problema',
#   'salud',
#   'mental',
#   'grave',
#   'sospecho',
#   'mismo',
#   'ano',
#   'puede',
#   'quede',
#   'discapacitado',
#   'fallezca',
#   '(',
#   'abro',
#   'hilo'],
#  ['lopez',
#   'problema',
#   'salud',
#   'mental',
#   'grave',
#   'sospecho',
#   'mismo',
#   'ano',
#   'puede',
#   'quede',
#   'discapacitado',
#   'fallezca',
#   '(',
#   'abro',
#   'hilo'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['nota',
#   'falta',
#   'argumento',
#   'recurrir',
#   'mentira',
#   'ende',
#   'resentido',
#   'vendepatrias',
#   'chairo',
#   'cacabot',
#   'apoya',
#   'mafia',
#   'prian',
#   'arrasando',
#   'grandeza',
#   'mexico'],
#  ['llego',
#   'casa',
#   'moribundo',
#   'parecer',
#   'tenia',
#   'varios',
#   'dias',
#   'comer',
#   'ciego',
#   'parasitos',
#   'pegado',
#   'cuerpo',
#   'madera',
#   'arbol',
#   'descompuesto',
#   'ojala',
#   'pueda',
#   'salvar',
#   'espero',
#   'accidente',
#   'paso',
#   'obra',
#   'algun',
#   'chucha',
#   'madre',
#   'mal',
#   'parido'],
#  ['mejor', 'mocho', 'guebo'],
#  ['fumo', 'bebo', 'cojo'],
#  ['tambien', 'chavoruco', 'olvides'],
#  ['consigna',
#   'regimen',
#   'neoliberal',
#   'desmontar',
#   'privatizar',
#   'salud',
#   'publica',
#   'proceso',
#   'saquear',
#   'erario',
#   'cambio',
#   'regimen',
#   'pandemia',
#   'significado',
#   'exterminio',
#   'amplias',
#   'capas',
#   'poblacion',
#   'pido',
#   'vercomentardar'],
#  ['cuidado',
#   'hijo',
#   'mil',
#   'puta',
#   'anda',
#   'hackeando/robando',
#   'numeros',
#   'wsp',
#   'hoy',
#   'metio',
#   'numero',
#   'vacio',
#   'grupos',
#   'dr'],
#  ['ok', 'culpa', 'ser', 'mocho'],
#  ['moraleja',
#   'george',
#   'carlin',
#   'don',
#   'rickles',
#   'richard',
#   'jeni',
#   'haberse',
#   'ido',
#   'hbo',
#   'volviera',
#   'santurron',
#   'cobarde',
#   'sumiso',
#   'censor',
#   'despedido',
#   'primera'],
#  ['mal',
#   'perdedor',
#   'mal',
#   'jugador',
#   'puto',
#   'lloron',
#   'mierda',
#   'chantajista',
#   'siempre',
#   'quejandose',
#   'morder',
#   'banca',
#   'siempre',
#   'sido',
#   'privilegiado',
#   'hijo',
#   'puta',
#   'meten',
#   'jugar',
#   'empieza',
#   'hacer',
#   'cagadero',
#   'mala',
#   'cae',
#   'tormenton',
#   'pleno',
#   'juego',
#   'pinche',
#   'salado'],
#  ['profesor',
#   'querales',
#   'cancion',
#   'shakira',
#   'ciego',
#   'sordo',
#   'mudo',
#   'sera',
#   'logra',
#   'encontrar',
#   'palabras',
#   'adecuadas',
#   'poder',
#   'responder',
#   'firmeza',
#   'sera',
#   'tambien',
#   'recibe',
#   'ayuda',
#   'humanitaria',
#   '(',
#   'primas',
#   'tendra',
#   'temor',
#   'retiren'],
#  ['plaga',
#   'langosta',
#   'especie',
#   'enorme',
#   'chapulin',
#   'devorador',
#   'echenle',
#   'ojito'],
#  ['guaido',
#   'equipo',
#   'fraudulento',
#   'hace',
#   '1',
#   'ano',
#   '6',
#   'meses',
#   'embarrandole',
#   'cara',
#   'pais',
#   'puso',
#   'esperanzas',
#   'haciendo',
#   'llenando',
#   'cuentas',
#   'millones',
#   'dolares',
#   'duelale',
#   'duela',
#   'asi',
#   'peor',
#   'ciego',
#   'quiere',
#   'ver'],
#  ['elecciones',
#   'vienen',
#   'exigen',
#   'nunca',
#   'paz',
#   'social',
#   'texto',
#   'completo',
#   'i',
#   'antorchistas',
#   'opiniondeaquilescordova',
#   'antorcha',
#   'campesina'],
#  ['cae', 'puta', 'vaina', 'mano', 'cara', 'verguenza', '[', ']'],
#  ['feliz',
#   'cumpleanos',
#   'roman',
#   'maximo',
#   'idolo',
#   'boca',
#   'actual',
#   'vicepresidente',
#   'segundo',
#   'club',
#   'festejo',
#   'dejale',
#   'saludo'],
#  ['creo',
#   'senador',
#   'politico',
#   'mas',
#   'centrado',
#   '4tatransformacion',
#   'habla',
#   'realidad',
#   'pais',
#   'ser',
#   'ciego',
#   'lamesuelas',
#   'gusta',
#   'hoy',
#   'busca',
#   'desacreditar',
#   'monreal'],
#  ['puto', 'asco', 'dio', 'ver', 'video'],
#  ['jodido',
#   'paguen',
#   'miseria',
#   'termines',
#   'contagiandote',
#   'covid',
#   'luego',
#   'responsabilicen',
#   'contagiar',
#   '200',
#   'personas',
#   'maquila',
#   'obligo',
#   'seguir',
#   'presentandote',
#   'trabajar',
#   'despedian'],
#  ['programasvtv',
#   '|',
#   'conoce',
#   'medidas',
#   'seguridad',
#   'implementadas',
#   'fronterizos',
#   'mas',
#   'detalles',
#   'programa',
#   'caraboboesvictoriapatria'],
#  ['tuit',
#   'mal',
#   'brazo',
#   'mocho',
#   'pito',
#   'seria',
#   'pito',
#   'unpopular',
#   'opinion',
#   'expresa',
#   'ninguna',
#   'opinion'],
#  ['puto', 'robo'],
#  ['exacto',
#   'tal',
#   'cuestion',
#   'genero',
#   'sino',
#   'sentimientos',
#   'sensaciones',
#   'emociones'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['mas',
#   'mocho',
#   'mas',
#   'religiosos',
#   'mas',
#   'estan',
#   'coludidos',
#   'malotes',
#   'mas',
#   'doblemoralistas',
#   'mas',
#   'ojetes',
#   'mas',
#   'gandallas'],
#  ['preso',
#   'hizo',
#   'viral',
#   'subir',
#   'tiktoks',
#   'gente',
#   'festeja',
#   'delito',
#   'apunalo',
#   '11',
#   'veces',
#   'nena',
#   'sigan',
#   'festejandole',
#   'hijos',
#   'puta',
#   'encima',
#   'justifican',
#   'derechos',
#   'humanos',
#   'ojala',
#   'mueran'],
#  ['mocho', 'vi'],
#  ['respuestas',
#   'dudas',
#   'polvo',
#   'sahara',
#   'cuba',
#   'ademas',
#   'imagenes',
#   'enviadas',
#   'propias',
#   'palabras',
#   'luna',
#   'fase',
#   'luna',
#   'nueva',
#   'puesta',
#   'sol',
#   'ciudad',
#   'ciego',
#   'saharandust'],
#  ['hola',
#   'ustedes',
#   'sabian',
#   'si',
#   'sigo',
#   'interactuar',
#   'flashear',
#   'confianza',
#   '[',
#   ']',
#   'si',
#   'hacen',
#   'mierda',
#   'siguen',
#   'interactuemos',
#   'puto',
#   'lee'],
#  ['siempre',
#   'derechos',
#   'mujeres',
#   'ninas',
#   'violados',
#   'colombia',
#   'dia',
#   'aproximadamente',
#   'violan',
#   '55',
#   'ninas',
#   'adolescentes',
#   'tipo',
#   'hombres',
#   'crian',
#   'pais',
#   'marchitos',
#   'luego',
#   'mujer',
#   'indigna',
#   'reclama',
#   'feminazi'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['ver',
#   'hijo',
#   'puta',
#   'madre',
#   'ustedes',
#   'escogimos',
#   'mierda',
#   'servicio',
#   'mejor',
#   'postor',
#   'propios',
#   'intereses',
#   'vamos',
#   'quitar',
#   'bola',
#   'mierdas'],
#  ['generacion',
#   'zoomers',
#   'tan',
#   'socialmente',
#   'comprometidos',
#   '(',
#   'quienes'],
#  ['jajajaja', 'pobrecito', 'chairo', 'tan', 'hocicon', 'pocos', 'huevos'],
#  ['acuerdense',
#   'mas',
#   'rato',
#   'tendenciatodo',
#   'festejando',
#   '7',
#   'millones',
#   'nini'],
#  ['triste',
#   'verdad',
#   'mayoria',
#   'argenta',
#   'cerebro',
#   'pjotista',
#   'lavado',
#   'zombie',
#   'ciego',
#   'sordo',
#   'vota',
#   'boleta',
#   'dicen',
#   'ponen',
#   'mano',
#   'casi',
#   '60',
#   'anos',
#   'visto',
#   'siempre',
#   'ignorancia'],
#  ['si',
#   'supieran',
#   'favorito',
#   'ser',
#   'insultado',
#   'chaira',
#   'gacha',
#   'mantenida',
#   'chairo',
#   'idem'],
#  ['maldito', 'coronavirus', 'demonio', 'jodido', 'bueno'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['messi', 'riquelme', 'feliz', 'cumpleanos', 'bestias'],
#  ['fuck', 'tan', 'genial', 'luz', 'dejado', 'ciego', 'ahhhhh'],
#  ['instalamos', 'nueva', 'ram', 'debemos', 'configurar', 'pc'],
#  ['jajaja',
#   'quisieras',
#   'asi',
#   'nini',
#   'dices',
#   'jajaja',
#   'vivo',
#   'salvador',
#   'propia',
#   'empresa',
#   'pequena',
#   'jefe',
#   'pagado',
#   'tirar',
#   'mierda',
#   'gobierno',
#   'anda',
#   'corretear',
#   'bus',
#   'pobre'],
#  ['mexico',
#   'existe',
#   'mejor',
#   'descripcion',
#   'paladin',
#   'mocho',
#   'apoteosico',
#   'mentiroso',
#   'mezquino'],
#  ['preso',
#   'hizo',
#   'viral',
#   'subir',
#   'tiktoks',
#   'gente',
#   'festeja',
#   'delito',
#   'apunalo',
#   '11',
#   'veces',
#   'nena',
#   'sigan',
#   'festejandole',
#   'hijos',
#   'puta',
#   'encima',
#   'justifican',
#   'derechos',
#   'humanos',
#   'ojala',
#   'mueran'],
#  ['chairo',
#   'discriminamos',
#   'ser',
#   'chairopitecus',
#   'tener',
#   'menor',
#   'coeficiente',
#   'intelectual',
#   '-',
#   'preferencia',
#   'sexual',
#   'creencia',
#   'religiosa',
#   'color',
#   'piel',
#   'etc',
#   'motivo',
#   'discrimacion',
#   'si',
#   'entiendes'],
#  ['ser', 'maricon', 'ser', 'mujer', 'dicho', 'chaval', 'calle', 'sjdhskdh'],
#  ['niego',
#   'romantizar',
#   'estabamos',
#   'mejor',
#   'pena',
#   'nieto',
#   'u',
#   'expresidentes',
#   'menos',
#   'mas',
#   'gobernante',
#   'igual',
#   'jodido',
#   'insisto',
#   'cambio',
#   'gobierno',
#   'aplaude',
#   'revisa',
#   'exige'],
#  ['mas',
#   'vaya',
#   'digale',
#   'pensionado',
#   'viejo',
#   '85',
#   'anos',
#   'q',
#   'juegue',
#   'mmo',
#   'q',
#   'genere',
#   'ingresos',
#   'q',
#   'salga',
#   'calle',
#   'ponga',
#   'creativo',
#   'q',
#   'consiga',
#   'sustento',
#   'diario',
#   'x',
#   'seres',
#   'tan',
#   'individualista',
#   'usted',
#   'q',
#   'pais',
#   'jodido'],
#  ['wey',
#   'cuento',
#   '(',
#   '(',
#   'akxjskkd',
#   'queria',
#   'verlo',
#   'spoilee',
#   'manhwa',
#   'creia',
#   'lancchan',
#   'quedaba',
#   'ciego',
#   'chile',
#   'veia',
#   'iguales',
#   'dije',
#   'neeeel',
#   'mamadas',
#   'entro',
#   'olvido',
#   'descubri',
#   'protas',
#   '('],
#  ['haces',
#   'saque',
#   'puto',
#   'lado',
#   'naco',
#   'mames',
#   'cabron',
#   'pedo',
#   'aun',
#   'asi',
#   'extrano'],
#  ['si',
#   'preguntamos',
#   'chairo',
#   'privilegios',
#   'refiere',
#   'habla',
#   'perdimos',
#   'conservador',
#   'neoliberalismo',
#   'sabria',
#   'contestar'],
#  ['2021',
#   '2026',
#   'mas',
#   'alla',
#   'necesitamos',
#   'mujeres',
#   'poder',
#   'tambien',
#   'peligroso',
#   'mira',
#   'rosario',
#   'jodido'],
#  ['hijo', 'puto', 'padre'],
#  ['pa', 'karla', 'panini', 'toda', 'puta', 'culpa'],
#  ['siganle', 'siganle', 'junio', 'sorprendeme', 'nini', 'niniiiiii'],
#  ['nuevo', 'video', 'nini', 'posiciona', '1', 'tendencias', 'mexico'],
#  ['peor',
#   'conde',
#   'andaba',
#   'puto',
#   'ay',
#   'igual',
#   'imposible',
#   'amar',
#   'max'],
#  ['ver',
#   'ensenanos',
#   'dice',
#   'chairo',
#   'mas',
#   'pndejo',
#   'puedes',
#   'ser',
#   'guste',
#   'insulten',
#   'falten',
#   'respeto',
#   'significa',
#   'demas',
#   'vayan',
#   'dejar'],
#  ['buenos',
#   'dias',
#   'necesito',
#   'ayuda',
#   'difundir',
#   'campana',
#   'gofundme',
#   'enfermo',
#   'esclerosis',
#   'multiple',
#   'eat',
#   'enfermedad',
#   'discapacitado',
#   'dejo',
#   'link',
#   'gofundme'],
#  ['pesimista', 'proyeccion', 'fmi', 'economia', 'mexico', 'amlo'],
#  ['chairo', 'maldito'],
#  ['retonamndo', 'hace', '8', 'dias', 'duda', 'naco', 'codos', 'grises'],
#  ['virus',
#   'maricon',
#   'fallece',
#   'polemico',
#   'cronista',
#   'canal',
#   '6',
#   'pepe',
#   'ruiz'],
#  ['repente'],
#  ['resulta',
#   'the',
#   'pokemon',
#   'company',
#   'da',
#   'tencent',
#   'puto',
#   'moba',
#   'game',
#   'freak',
#   'tt',
#   'puedo',
#   'mas',
#   'muchisimo',
#   'hablais',
#   'tener',
#   'idea',
#   'funciona',
#   'franquicia'],
#  ['trama',
#   'venezolana',
#   'toca',
#   'amlo',
#   'empresarios',
#   'mexicanos',
#   'columna',
#   'via'],
#  ['nunca', 'puta', 'vida', 'disculpes', 'ser'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['salvar',
#   'puto',
#   'turismo',
#   'turismo',
#   'magnates',
#   'turismo',
#   'va',
#   'costar',
#   '200',
#   'veces',
#   'mas',
#   'dejarlo',
#   'caer'],
#  ['mocho', 'cota'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['recuerda',
#   'afroamericanos',
#   'racistas',
#   'mexicanos',
#   'eeuuo',
#   'israelies',
#   'dictadores',
#   'palestinospero',
#   'si',
#   'hablan',
#   'eeuu',
#   'prensa',
#   'sociedad',
#   'hipocrita',
#   'mojigata',
#   'blackmatters',
#   'llega',
#   'ser',
#   'farsa',
#   'si',
#   'discute',
#   'serio'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['ojoaldato',
#   'cifras',
#   'van',
#   'aumento',
#   'publico',
#   'activo',
#   'bomba',
#   'tiempo',
#   'diputados',
#   'hicieron',
#   'mecha',
#   'mas',
#   'bomba',
#   'mas',
#   'grande',
#   'solo',
#   'ciego',
#   'da',
#   'cuenta',
#   'nayib',
#   'hizo',
#   'pudo'],
#  ['q',
#   'bn',
#   'adios',
#   'puto',
#   'niga',
#   'mierda',
#   'pinche',
#   'nino',
#   'rata',
#   'pendejo',
#   'deje',
#   'callado',
#   'mijo',
#   'perro'],
#  ['idiotas',
#   'q',
#   'apenas',
#   'leen',
#   'twitter',
#   'mocho',
#   'd',
#   'supuesta',
#   'noticia',
#   'd',
#   'guaido',
#   'enseguida',
#   'retwittear'],
#  ['averio',
#   'sismo',
#   'puente',
#   'calderon',
#   'mitla',
#   'oaxaca',
#   'si',
#   'llama',
#   'igual',
#   'jefe',
#   'genaro',
#   'garcia',
#   'luna',
#   'mismo',
#   'preso',
#   'amparar',
#   'narcotrafico',
#   'sexenio',
#   'ver',
#   'si',
#   'hace',
#   'cooperacha',
#   'reparacion'],
#  ['puta', 'alguien', 'puede', 'ayudar', 'saber', 'drake'],
#  ['nini', 'odia'],
#  ['gobierno',
#   'ciego',
#   'ahora',
#   'salir',
#   'si',
#   'necesidad',
#   'dice',
#   'alguien',
#   'necesidad',
#   'salir',
#   'ridiculez'],
#  ['17',
#   'marzo',
#   'pedro',
#   'sanchez',
#   'dijo',
#   'textualmente',
#   'crisis',
#   'hoy',
#   'fmi',
#   'coloca',
#   'espana',
#   'cabeza',
#   'hundimiento',
#   'economico',
#   'presidente',
#   'economia',
#   'puto',
#   'lince',
#   'oraculo'],
#  ['gol',
#   'mejor',
#   'futbolista',
#   'historia',
#   'mexico',
#   'hijos',
#   'puta',
#   'madre',
#   'raullando'],
#  ['ayudanos', 'plis'],
#  ['nuevo', 'video', 'nini', 'posiciona', '1', 'tendencias', 'mexico'],
#  ['ud',
#   'pregunte',
#   'precio',
#   'mocho',
#   'esponja',
#   'fregar',
#   'digan',
#   '300000bss',
#   'asombre',
#   'solo',
#   'recuerde',
#   'venezuela',
#   'gringosbueno'],
#  ['jodidos',
#   'bots',
#   'puro',
#   'ignorante',
#   'ponen',
#   'pelear',
#   'aqui',
#   'chascos',
#   'beca',
#   'nini'],
#  ['vestir',
#   'ropa',
#   'marca',
#   'ser',
#   'jodido',
#   'recuerda',
#   'familia',
#   'alimentar',
#   'sociedad',
#   'pendeja',
#   'impresionar'],
#  ['menos',
#   'sintio',
#   'comisionado',
#   'gordon',
#   'puto',
#   'telefono',
#   'rojo',
#   'hablando',
#   'nadie',
#   'salio',
#   'ver',
#   'pedo'],
#  ['puta', 'idea'],
#  ['plaza',
#   'mayo',
#   'hacia',
#   'ano',
#   '1895-1900',
#   'puede',
#   'observar',
#   'cabildo',
#   'avenida',
#   'mayo',
#   'fotografia'],
#  ['1',
#   'ofrecieron',
#   'consumir',
#   'droga',
#   '14',
#   'anos',
#   'primero',
#   'q',
#   'vino',
#   'mente',
#   'papa',
#   'va',
#   'matar',
#   'dije',
#   'ademas',
#   'inmenso',
#   'carino',
#   'q',
#   'dio',
#   'viejo',
#   'tambien',
#   'trasmitio',
#   'q',
#   'jodido',
#   'estricto',
#   'gracias',
#   'jamas',
#   'consumi',
#   'droga',
#   'padres',
#   'amigos'],
#  ['cora',
#   'mocho',
#   'sellado',
#   'tetra',
#   'karma',
#   'roto',
#   'dijo',
#   'maldita',
#   'coneja'],
#  ['gustan', 'fotos', 'digamos'],
#  ['lorenzo',
#   'cordoba',
#   'murayamale',
#   'estan',
#   'jugando',
#   'vivo',
#   'vencidas',
#   'presidente',
#   'solo',
#   'olvida',
#   'apoyo',
#   'presidente',
#   'si',
#   'buscannos',
#   'van',
#   'encontrar',
#   'fueralorenzocordovadeline'],
#  ['recibes', 'beca', 'nini', 'simplemente', 'fanatico'],
#  ['nose', 'ustedes', 'odio', 'puto', 'calor'],
#  ['llorar', 'chairo'],
#  ...]

# %%
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec

path = get_tmpfile("./data/word2vec.model")

model = Word2Vec(pd_Todex2, size=100, window=5, min_count=1, workers=4)
model.wv.save_word2vec_format("./data/word2vec.txt")

# %% [markdown]
# gzip word2vec.txt
#
# python -m spacy init-model en prueba --vectors-loc word2vec.txt.gz
# nlp = spacy.load('./data/spacy.word2vec.model/')

# %%
nlp = spacy.load('./data/prueba2/')
# Out:
# /home/francisco/anaconda3/lib/python3.7/site-packages/spacy/_ml.py:304: UserWarning: [W019] Changing vectors name from en_model.vectors to en_model.vectors_8673, to avoid clash with previously loaded vectors. See Issue #3853.
#   warnings.warn(Warnings.W019.format(old=old_name, new=new_name))

# %%
nlp("pinche gordo AMLO").vector
# Out:
# array([ 2.20476580e-03,  4.23001917e-03, -2.11123450e-04, -1.09873740e-02,
#        -1.03179114e-02, -6.71098614e-03, -1.17185181e-02,  4.43837559e-03,
#        -2.59596412e-03, -1.09160261e-03, -8.24459922e-03, -1.01763103e-02,
#         2.12113792e-03,  9.88899637e-03,  1.19575234e-02,  2.17716675e-02,
#        -2.51885678e-04,  1.14552947e-02, -4.65956377e-03,  3.17326910e-03,
#         1.11320978e-02, -2.09585158e-03, -1.04299895e-02, -9.36006382e-03,
#        -1.77918095e-02, -2.00929455e-02, -5.02394419e-03, -8.45382269e-03,
#         5.55529306e-03, -1.15413684e-04, -1.90410158e-03,  9.42940172e-03,
#         8.16755556e-03,  3.32939345e-03, -2.29346007e-03, -8.29139818e-03,
#        -3.38659302e-04, -2.23392388e-03, -1.52943833e-02, -7.27310916e-03,
#        -1.12305088e-02, -3.49884685e-05, -7.65644992e-03, -2.71477643e-02,
#         1.90728959e-02, -1.73335441e-03,  1.66786450e-03,  4.28966759e-03,
#         2.43087392e-03, -4.78248578e-04, -1.82095647e-03, -1.20501558e-03,
#        -1.10203715e-03,  2.22710241e-02,  2.22666543e-02, -2.57443782e-04,
#        -1.70267560e-03,  1.53051205e-02,  5.56170428e-03,  1.32006584e-02,
#        -8.69877357e-03, -5.70620969e-03, -2.33195233e-03,  1.46335354e-02,
#        -2.93601095e-03, -2.11607269e-03,  1.34360464e-02, -2.46523501e-04,
#         9.05208476e-03, -1.05906306e-02, -5.59552340e-03,  1.40453654e-03,
#         1.96890044e-03, -1.88774634e-02, -1.23029510e-02, -7.49971205e-03,
#        -9.76587296e-04,  7.78680667e-03,  6.73097558e-03, -4.41955263e-03,
#         4.60784184e-03,  2.13356931e-02,  9.28757060e-03,  2.61316728e-03,
#        -1.68530329e-03, -5.19744167e-03,  1.06004728e-02, -1.18762562e-02,
#         2.29879823e-02,  8.93361960e-03,  9.93004069e-03,  6.24325266e-03,
#        -8.58686026e-03, -1.29478769e-02,  1.74713153e-02,  1.11586740e-02,
#        -1.91701704e-03, -2.63837329e-03, -6.48943335e-03, -3.03093088e-03],
#       dtype=float32)

# %% [markdown]
# # NEXT STEP
#
# - Conexión aws y bajar todo en un data frame
# - correr el pipe de arriba

# %%
import sklearn

# %%
pd.__version__
# Out:
# '1.0.1'
